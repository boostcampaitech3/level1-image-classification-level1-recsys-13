# %% [markdown]
# # 패키지 로드

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
import torch.optim as optim

from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from torchvision.transforms import Resize, ToTensor, Normalize

import os
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

from PIL import Image

from tqdm import tqdm
import time

from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %% [markdown]
# # 학습 설정

# %%
'''

학습 설정

추후에 argparser로 설정하면 될 듯

'''

train_data_dir = '../input/data/train/'
submission_data_dir = '../input/data/eval/'

train_image_dir = '../input/data/train/images'
submission_image_dir = '../input/data/eval/images'

model_dir = '../model/'

test_size = 0.2
fold_num = 5
seed = 22

lr = 0.01
device = 'cuda' if torch.cuda.is_available() else 'cpu'
batch_size = 128
epochs = 10

image_size = (128, 128)
image_normal_mean = (0.5, 0.5, 0.5)
image_normal_std = (0.2, 0.2, 0.2)

# %% [markdown]
# # 데이터 로드 및 전처리

# %%
df = pd.read_csv(train_data_dir + 'train.csv')
submission = pd.read_csv(submission_data_dir + 'info.csv')

# %%
'''

이상치 처리

'''

df.loc[df[df['id'] == '006359'].index, 'gender'] = 'male'
df.loc[df[df['id'] == '006359'].index, :]
# Out:
#           id gender   race  age                    path
# 2399  006359   male  Asian   18  006359_female_Asian_18

# %%
'''

학습 데이터셋 구축

'''
def get_age_group(x):
    if x < 30: return 0
    elif x < 60: return 1
    else: return 2

def get_gender_group(x):
    if x == 'male': return 0
    else: return 1

def get_train_df(df):
    train_df = []

    for idx, line in enumerate(tqdm(df.iloc)):
        for file in list(os.listdir(os.path.join(train_image_dir, line['path']))):
            if file[0] == '.':
                continue
            if file.split('.')[0] == 'normal':
                mask = 2
            elif file.split('.')[0] == 'incorrect_mask':
                mask = 1
            else:
                mask = 0
                
            mask_state = file.split('.')[0]
            gender_group = get_gender_group(line['gender'])
            age_group = get_age_group(line['age'])
            
            data = {
                'id' : line['id'],
                'gender' : line['gender'],
                'gender_group' : gender_group,
                'age' : line['age'],
                'age_group' : age_group,
                'mask_state': mask_state,
                'mask' : mask,
                'path': os.path.join(train_image_dir, line['path'], file),
                'label': mask * 6 + gender_group * 3 + age_group
            }
            
            train_df.append(data)
            
    train_df = pd.DataFrame(train_df)
    
    return train_df

train_df = get_train_df(df = df)
# Out:
# 2700it [00:00, 2772.54it/s]

# %%
'''

데이터셋 분리

'''

train_idx, test_idx = train_test_split(train_df['label'], train_size = 1 - test_size, random_state = seed, stratify = train_df['label'])
                                      
train_set, test_set = train_df.iloc[train_idx.index, :].reset_index(drop = True), train_df.iloc[test_idx.index, :].reset_index(drop = True)

# %% [markdown]
# # 모델 설정

# %%
'''

ResNet 모델 구축

나동빈님 코드 참고

https://github.com/ndb796/Deep-Learning-Paper-Review-and-Practice/blob/master/code_practices/ResNet18_MNIST_Train.ipynb

'''

# ResNet18을 위해 최대한 간단히 수정한 BasicBlock 클래스 정의
class BasicBlock(nn.Module):
    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()

        # 3x3 필터를 사용 (너비와 높이를 줄일 때는 stride 값 조절)
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes) # 배치 정규화(batch normalization)

        # 3x3 필터를 사용 (패딩을 1만큼 주기 때문에 너비와 높이가 동일)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes) # 배치 정규화(batch normalization)

        self.shortcut = nn.Sequential() # identity인 경우
        if stride != 1: # stride가 1이 아니라면, Identity mapping이 아닌 경우
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x) # (핵심) skip connection
        out = F.relu(out)
        return out


# ResNet 클래스 정의
class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 64

        # 64개의 3x3 필터(filter)를 사용
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes # 다음 레이어를 위해 채널 수 변경
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 16)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

# %% [markdown]
# # 데이터셋 구축

# %%
'''

Sample_submission 코드 참고

증강 데이터 생성은 본 함수에 추가할 것

데이터 셋 구축

'''

class CustomDataset(Dataset):
    def __init__(self, df, transform, train = True):
        self.train = train
        self.df = df
        if self.train:
            self.img_paths = self.df['path'].tolist()
            self.genders = self.df['gender_group'].tolist()
            self.ages = self.df['age_group'].tolist()
            self.masks = self.df['mask'].tolist()
            self.labels = self.df['label'].tolist()
        else:
            self.img_paths = [os.path.join(submission_image_dir, img_id) for img_id in self.df.ImageID]
        self.transform = transform

    def __getitem__(self, index):
        image = Image.open(self.img_paths[index])
        if self.transform:
            image = self.transform(image)
        
        if self.train:
            label = torch.tensor(self.labels[index])
            age = torch.tensor(self.ages[index])
            gender = torch.tensor(self.genders[index])
            mask = torch.tensor(self.masks[index])
            return image, label, age, gender, mask
        
        else: return image

    def __len__(self):
        return len(self.img_paths)

# %% [markdown]
# # 학습 함수

# %%
def get_f1_score(y_true, y_pred):
    return f1_score(y_true, y_pred, average='macro')

def get_acc_score(y_true, y_pred):
    return accuracy_score(y_true, y_pred)

def model_train(model, optimizer, criterion, images, targets):
    model.train()
    
    images, targets = images.to(device), targets.to(device)
    optimizer.zero_grad()
    
    benign_outputs = model(images)
    loss = criterion(benign_outputs, targets)
    loss.backward()
    
    optimizer.step()
    
    train_loss = loss.item()
    _, predicted = benign_outputs.max(1)
    
    correct = predicted.eq(targets).sum().item()
    
    fl_socre = get_f1_score(y_true = targets.cpu().tolist(), y_pred = predicted.cpu().tolist())
    
    return train_loss, correct, fl_socre

def batch_train(model, optimizer, criterion, images, targets, train_loss, train_acc, train_fi_score):
    loss, acc, fi_score = model_train(model = model, optimizer = optimizer, criterion = criterion, images = images, targets = targets)
    train_loss += loss
    train_acc += acc
    train_fi_score += fi_score

    return train_loss, train_acc, train_fi_score


def model_eval(model, criterion, images, targets):
    model.eval()
    with torch.no_grad():
        images, targets = images.to(device), targets.to(device)
        benign_outputs = model(images)
        loss = criterion(benign_outputs, targets)
        
        val_loss = loss.item()
        _, predicted = benign_outputs.max(1)
        
        correct = predicted.eq(targets).sum().item()
        fl_socre = get_f1_score(y_true = targets.cpu().tolist(), y_pred = predicted.cpu().tolist())
   
    return val_loss, correct, fl_socre

def batch_eval(model, criterion, images, targets, val_loss, val_acc, val_fi_score):
    loss, acc, fi_score = model_eval(model = model, criterion = criterion, images = images, targets = targets)
    val_loss += loss
    val_acc += acc
    val_fi_score += fi_score

    return val_loss, val_acc, val_fi_score

def ensemble(model, images):
    model.eval()
    all_predictions = []
    with torch.no_grad():
        images = images.to(device)
        pred = model(images)
        pred = pred.softmax(dim = 1)
        all_predictions.extend(pred.cpu().numpy())
    
    return all_predictions

def get_lr(optimizer):
    for param_group in optimizer.param_groups:
        return param_group['lr']

def get_loss(loss, acc, fi_score, data_loder, total):
    loss /= len(data_loder)
    acc /= total
    fi_score /= len(data_loder)

    return loss, acc, fi_score

# %% [markdown]
# # 학습

# %%
'''

데이터 전처리 함수

데이터 증강 등의 함수를 수정해서 사용하면 될 듯 함

'''

transform = transforms.Compose([
    Resize(image_size, Image.BILINEAR),
    ToTensor(),
    Normalize(mean=image_normal_mean, std=image_normal_std),
])

# %%
'''

학습 시작

'''
total_start_time = time.time()

skf = StratifiedKFold(n_splits = fold_num, random_state = seed, shuffle = True)

criterion = nn.CrossEntropyLoss()

for now_fold_num, (trn_idx, val_idx) in enumerate(skf.split(train_set, train_set['label'])):
    fold_start_time = time.time()
    
    # 데이터 정의
    trn_df = train_set.iloc[trn_idx, :]
    val_df = train_set.iloc[val_idx, :]
    
    trn_dataset = CustomDataset(df = trn_df, 
                                transform = transform, 
                                train = True)
    
    val_dataset = CustomDataset(df = val_df, 
                                transform = transform, 
                                train = True)
    
    train_loder = DataLoader(
    trn_dataset,
    batch_size = batch_size,
    shuffle=True,
    )
    
    val_loder = DataLoader(
    val_dataset,
    batch_size = batch_size,
    shuffle = False,
    )
    
    # 모델 정의
    label_model = ResNet(block = BasicBlock, 
                         num_blocks = [2, 2, 2, 2],
                         num_classes = 18).to(device)
    
    mask_model = ResNet(block = BasicBlock, 
                        num_blocks = [2, 2, 2, 2], 
                        num_classes = 3).to(device)
    
    gender_model = ResNet(block = BasicBlock, 
                          num_blocks = [2, 2, 2, 2], 
                          num_classes = 2).to(device)
    
    age_model = ResNet(block = BasicBlock, 
                       num_blocks = [2, 2, 2, 2], 
                       num_classes = 3).to(device)
    
    # optimizer 설정
    label_optimizer = optim.Adam(label_model.parameters(), lr=lr)
    mask_optimizer = optim.Adam(mask_model.parameters(), lr=lr)
    gender_optimizer = optim.Adam(gender_model.parameters(), lr=lr)
    age_optimizer = optim.Adam(age_model.parameters(), lr=lr)
    
    # scheduler 설정
    label_scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(label_optimizer, 'min', factor = 0.1, eps = 1e-09, patience = 5)
    mask_scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(mask_optimizer, 'min', factor = 0.1, eps = 1e-09, patience = 5)
    gender_scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(gender_optimizer, 'min', factor = 0.1, eps = 1e-09, patience = 5)
    age_scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(age_optimizer, 'min', factor = 0.1, eps = 1e-09, patience = 5)
    
    # besf_metric 설정
    label_besf_fi = 0
    mask_besf_fi = 0
    gender_besf_fi = 0
    age_besf_fi = 0
    
    for epoch in range(1, epochs + 1):
        epoch_start_time = time.time()
        
        # 메트릭 정의
        total = 0
        train_label_loss, train_label_acc, train_label_fi_score, val_label_loss, val_label_acc, val_label_fi_score = 0, 0, 0, 0, 0, 0
        train_mask_loss, train_mask_acc, train_mask_fi_score, val_mask_loss, val_mask_acc, val_mask_fi_score = 0, 0, 0, 0, 0, 0
        train_gender_loss, train_gender_acc, train_gender_fi_score, val_gender_loss, val_gender_acc, val_gender_fi_score = 0, 0, 0, 0, 0, 0
        train_age_loss, train_age_acc, train_age_fi_score, val_age_loss, val_age_acc, val_age_fi_score = 0, 0, 0, 0, 0, 0
        
        # 학습
        for images, labels, ages, genders, masks in train_loder:
            total += labels.size(0)
            
            train_label_loss, train_label_acc, train_label_fi_score = batch_train(model = label_model, 
                                                                                   optimizer = label_optimizer, 
                                                                                   criterion = criterion, 
                                                                                   images = images, 
                                                                                   targets = labels, 
                                                                                   train_loss = train_label_loss, 
                                                                                   train_acc = train_label_acc, 
                                                                                   train_fi_score = train_label_fi_score)
            
            train_mask_loss, train_mask_acc, train_mask_fi_score = batch_train(model = mask_model, 
                                                                                   optimizer = mask_optimizer, 
                                                                                   criterion = criterion, 
                                                                                   images = images, 
                                                                                   targets = masks, 
                                                                                   train_loss = train_mask_loss, 
                                                                                   train_acc = train_mask_acc, 
                                                                                   train_fi_score = train_mask_fi_score)
            
            train_gender_loss, train_gender_acc, train_gender_fi_score = batch_train(model = gender_model, 
                                                                                   optimizer = gender_optimizer, 
                                                                                   criterion = criterion, 
                                                                                   images = images, 
                                                                                   targets = genders, 
                                                                                   train_loss = train_gender_loss, 
                                                                                   train_acc = train_gender_acc, 
                                                                                   train_fi_score = train_gender_fi_score)
            
            
            train_age_loss, train_age_acc, train_age_fi_score = batch_train(model = age_model, 
                                                                                   optimizer = age_optimizer, 
                                                                                   criterion = criterion, 
                                                                                   images = images, 
                                                                                   targets = ages, 
                                                                                   train_loss = train_age_loss, 
                                                                                   train_acc = train_age_acc, 
                                                                                   train_fi_score = train_age_fi_score)
            
        
        # total_loss 계산
        train_label_loss, train_label_acc, train_label_fi_score = get_loss(loss = train_label_loss, 
                                                                           acc = train_label_acc, 
                                                                           fi_score = train_label_fi_score, 
                                                                           data_loder = train_loder, 
                                                                           total = total)
        
        train_mask_loss, train_mask_acc, train_mask_fi_score = get_loss(loss = train_mask_loss, 
                                                                           acc = train_mask_acc, 
                                                                           fi_score = train_mask_fi_score, 
                                                                           data_loder = train_loder, 
                                                                           total = total)
        
        train_gender_loss, train_gender_acc, train_gender_fi_score = get_loss(loss = train_gender_loss, 
                                                                           acc = train_gender_acc, 
                                                                           fi_score = train_gender_fi_score, 
                                                                           data_loder = train_loder, 
                                                                           total = total)
        
        train_age_loss, train_age_acc, train_age_fi_score = get_loss(loss = train_age_loss, 
                                                                           acc = train_age_acc, 
                                                                           fi_score = train_age_fi_score, 
                                                                           data_loder = train_loder, 
                                                                           total = total)
        
        # 평가
        total = 0
        for images, labels, ages, genders, masks in val_loder:
            total += labels.size(0)
            
            val_label_loss, val_label_acc, val_label_fi_score = batch_eval(model = label_model, 
                                                                           criterion = criterion, 
                                                                           images = images, 
                                                                           targets = labels, 
                                                                           val_loss = val_label_loss, 
                                                                           val_acc = val_label_acc, 
                                                                           val_fi_score = val_label_fi_score)
            
            val_mask_loss, val_mask_acc, val_mask_fi_score = batch_eval(model = mask_model, 
                                                                           criterion = criterion, 
                                                                           images = images, 
                                                                           targets = masks, 
                                                                           val_loss = val_mask_loss, 
                                                                           val_acc = val_mask_acc, 
                                                                           val_fi_score = val_mask_fi_score)
            
            val_gender_loss, val_gender_acc, val_gender_fi_score = batch_eval(model = gender_model, 
                                                                           criterion = criterion, 
                                                                           images = images, 
                                                                           targets = genders, 
                                                                           val_loss = val_gender_loss, 
                                                                           val_acc = val_gender_acc, 
                                                                           val_fi_score = val_gender_fi_score)
            
            val_age_loss, val_age_acc, val_age_fi_score = batch_eval(model = age_model, 
                                                                           criterion = criterion, 
                                                                           images = images, 
                                                                           targets = ages, 
                                                                           val_loss = val_age_loss, 
                                                                           val_acc = val_age_acc, 
                                                                           val_fi_score = val_age_fi_score)
            
        
        # total_loss 계산
        val_label_loss, val_label_acc, val_label_fi_score = get_loss(loss = val_label_loss, 
                                                                           acc = val_label_acc, 
                                                                           fi_score = val_label_fi_score, 
                                                                           data_loder = val_loder, 
                                                                           total = total)
        
        val_mask_loss, val_mask_acc, val_mask_fi_score = get_loss(loss = val_mask_loss, 
                                                                           acc = val_mask_acc, 
                                                                           fi_score = val_mask_fi_score, 
                                                                           data_loder = val_loder, 
                                                                           total = total)
        
        val_gender_loss, val_gender_acc, val_gender_fi_score = get_loss(loss = val_gender_loss, 
                                                                           acc = val_gender_acc, 
                                                                           fi_score = val_gender_fi_score, 
                                                                           data_loder = val_loder,
                                                                           total = total)
        
        val_age_loss, val_age_acc, val_age_fi_score = get_loss(loss = val_age_loss, 
                                                                           acc = val_age_acc, 
                                                                           fi_score = val_age_fi_score, 
                                                                           data_loder = val_loder, 
                                                                           total = total)
    
        
        # 학습 결과 출력
        model_li = ['label', 'mask', 'gender', 'age']
        for idx, (train_loss, train_acc, train_f1, val_loss, val_acc, val_fi) in enumerate([
                [train_label_loss, train_label_acc, train_label_fi_score, val_label_loss, val_label_acc, val_label_fi_score],
                [train_mask_loss, train_mask_acc, train_mask_fi_score, val_mask_loss, val_mask_acc, val_mask_fi_score],
                [train_gender_loss, train_gender_acc, train_gender_fi_score, val_gender_loss, val_gender_acc, val_gender_fi_score],
                [train_age_loss, train_age_acc, train_age_fi_score, val_age_loss, val_age_acc, val_age_fi_score],
            ]):
            if model_li[idx] == 'label' : lr = get_lr(optimizer = label_optimizer)
            elif model_li[idx] == 'mask' : lr = get_lr(optimizer = mask_optimizer)
            elif model_li[idx] == 'gender' : lr = get_lr(optimizer = gender_optimizer)
            elif model_li[idx] == 'age' : lr = get_lr(optimizer = age_optimizer)
            
            print(f'{now_fold_num + 1}fold, epoch: {epoch}, model: {model_li[idx]}, lr: {lr}, train_loss: {train_loss:.4f}, train_acc: {train_acc:.4f}, train_f1: {train_f1:.4f}, val_loss: {val_loss:.4f}, val_acc: {val_acc:.4f}, val_fi: {val_fi:.4f}')
        
        epoch_end_time = time.time()
        
        print(f'{now_fold_num + 1}fold, epoch: {epoch}, 학습시간: {epoch_end_time - epoch_start_time} \n')
        
        
        # 스케줄러
        label_scheduler.step(val_label_loss)
        mask_scheduler.step(val_mask_loss)
        gender_scheduler.step(val_gender_loss)
        age_scheduler.step(val_age_loss)
        
        
        # 모델 저장
        if label_besf_fi < val_label_fi_score:
            label_besf_fi = val_label_fi_score
            torch.save(label_model.state_dict(), model_dir + f'{now_fold_num + 1}fold_label_ResNet.pt')
        
        if mask_besf_fi < val_mask_fi_score:
            mask_besf_fi = val_mask_fi_score
            torch.save(mask_model.state_dict(), model_dir + f'{now_fold_num + 1}fold_mask_ResNet.pt')
            
        if gender_besf_fi < val_gender_fi_score:
            gender_besf_fi = val_gender_fi_score
            torch.save(gender_model.state_dict(), model_dir + f'{now_fold_num + 1}fold_gender_ResNet.pt')
            
        if age_besf_fi < val_age_fi_score:
            age_besf_fi = val_age_fi_score
            torch.save(age_model.state_dict(), model_dir + f'{now_fold_num + 1}fold_age_ResNet.pt')
    
    fold_end_time = time.time()
    
    print(f'{now_fold_num + 1}fold 훈련 시간: {fold_end_time - fold_start_time} \n')

total_end_time = time.time()
print(f'총 훈련 시간: {total_end_time - total_start_time}')
# Out:
# 1fold, epoch: 1, model: label, train_loss: 2.2048, train_acc: 0.3199, train_f1: 0.0886, val_loss: 2.4064, val_acc: 0.3882, val_fi: 0.1454
# 1fold, epoch: 1, model: mask, train_loss: 0.7584, train_acc: 0.7134, train_f1: 0.3468, val_loss: 0.7686, val_acc: 0.7202, val_fi: 0.3173
# 1fold, epoch: 1, model: gender, train_loss: 0.6844, train_acc: 0.6408, train_f1: 0.5046, val_loss: 0.7397, val_acc: 0.5843, val_fi: 0.5772
# 1fold, epoch: 1, model: age, train_loss: 0.6919, train_acc: 0.7156, train_f1: 0.4931, val_loss: 0.6872, val_acc: 0.7242, val_fi: 0.4987
# 1fold, epoch: 1, 학습시간: 289.9220771789551
#
# 1fold, epoch: 2, model: label, train_loss: 1.5342, train_acc: 0.5074, train_f1: 0.2452, val_loss: 1.4067, val_acc: 0.5483, val_fi: 0.3186
# 1fold, epoch: 2, model: mask, train_loss: 0.4158, train_acc: 0.8474, train_f1: 0.6832, val_loss: 0.4832, val_acc: 0.8767, val_fi: 0.7941
# 1fold, epoch: 2, model: gender, train_loss: 0.5358, train_acc: 0.7353, train_f1: 0.7135, val_loss: 0.4874, val_acc: 0.7725, val_fi: 0.7465
# 1fold, epoch: 2, model: age, train_loss: 0.5549, train_acc: 0.7799, train_f1: 0.5487, val_loss: 0.5145, val_acc: 0.7933, val_fi: 0.5462
# 1fold, epoch: 2, 학습시간: 288.4789705276489
#
# 1fold, epoch: 3, model: label, train_loss: 0.9974, train_acc: 0.6692, train_f1: 0.4718, val_loss: 1.9572, val_acc: 0.3558, val_fi: 0.2805
# 1fold, epoch: 3, model: mask, train_loss: 0.1685, train_acc: 0.9448, train_f1: 0.9135, val_loss: 0.2570, val_acc: 0.9120, val_fi: 0.8459
# 1fold, epoch: 3, model: gender, train_loss: 0.4431, train_acc: 0.7970, train_f1: 0.7817, val_loss: 1.0667, val_acc: 0.6627, val_fi: 0.5698
# 1fold, epoch: 3, model: age, train_loss: 0.4858, train_acc: 0.8051, train_f1: 0.5776, val_loss: 0.9284, val_acc: 0.7308, val_fi: 0.4968
# 1fold, epoch: 3, 학습시간: 288.3867299556732
#
# 1fold, epoch: 4, model: label, train_loss: 0.7806, train_acc: 0.7365, train_f1: 0.5591, val_loss: 0.8574, val_acc: 0.7057, val_fi: 0.5304
# 1fold, epoch: 4, model: mask, train_loss: 0.1033, train_acc: 0.9673, train_f1: 0.9500, val_loss: 0.2762, val_acc: 0.9038, val_fi: 0.8797
# 1fold, epoch: 4, model: gender, train_loss: 0.3567, train_acc: 0.8432, train_f1: 0.8329, val_loss: 0.8981, val_acc: 0.6653, val_fi: 0.6627
# 1fold, epoch: 4, model: age, train_loss: 0.4410, train_acc: 0.8242, train_f1: 0.6214, val_loss: 0.6304, val_acc: 0.7030, val_fi: 0.6252
# 1fold, epoch: 4, 학습시간: 288.19266080856323
#
# 1fold, epoch: 5, model: label, train_loss: 0.6269, train_acc: 0.7837, train_f1: 0.6097, val_loss: 1.2225, val_acc: 0.5810, val_fi: 0.4801
# 1fold, epoch: 5, model: mask, train_loss: 0.0845, train_acc: 0.9736, train_f1: 0.9593, val_loss: 0.2452, val_acc: 0.9355, val_fi: 0.8938
# 1fold, epoch: 5, model: gender, train_loss: 0.2708, train_acc: 0.8890, train_f1: 0.8823, val_loss: 0.2760, val_acc: 0.8882, val_fi: 0.8840
# 1fold, epoch: 5, model: age, train_loss: 0.3949, train_acc: 0.8426, train_f1: 0.6722, val_loss: 0.4693, val_acc: 0.8185, val_fi: 0.6321
# 1fold, epoch: 5, 학습시간: 288.9617347717285
#
# 1fold, epoch: 6, model: label, train_loss: 0.5299, train_acc: 0.8118, train_f1: 0.6561, val_loss: 1.0609, val_acc: 0.6700, val_fi: 0.5369
# 1fold, epoch: 6, model: mask, train_loss: 0.0700, train_acc: 0.9785, train_f1: 0.9676, val_loss: 0.0914, val_acc: 0.9709, val_fi: 0.9573
# 1fold, epoch: 6, model: gender, train_loss: 0.2286, train_acc: 0.9093, train_f1: 0.9037, val_loss: 0.3260, val_acc: 0.8614, val_fi: 0.8594
# 1fold, epoch: 6, model: age, train_loss: 0.3809, train_acc: 0.8444, train_f1: 0.6700, val_loss: 0.4571, val_acc: 0.8046, val_fi: 0.6929
# 1fold, epoch: 6, 학습시간: 289.95224142074585
#
# 1fold, epoch: 7, model: label, train_loss: 0.4565, train_acc: 0.8400, train_f1: 0.6871, val_loss: 1.5092, val_acc: 0.6065, val_fi: 0.5266
# 1fold, epoch: 7, model: mask, train_loss: 0.0501, train_acc: 0.9850, train_f1: 0.9766, val_loss: 0.4176, val_acc: 0.9117, val_fi: 0.8437
# 1fold, epoch: 7, model: gender, train_loss: 0.1879, train_acc: 0.9271, train_f1: 0.9226, val_loss: 0.3246, val_acc: 0.8737, val_fi: 0.8709
# 1fold, epoch: 7, model: age, train_loss: 0.3673, train_acc: 0.8529, train_f1: 0.6993, val_loss: 0.4725, val_acc: 0.8059, val_fi: 0.5546
# 1fold, epoch: 7, 학습시간: 291.64513516426086
#
# 1fold, epoch: 8, model: label, train_loss: 0.3919, train_acc: 0.8596, train_f1: 0.7325, val_loss: 0.5405, val_acc: 0.8009, val_fi: 0.6595
# 1fold, epoch: 8, model: mask, train_loss: 0.0457, train_acc: 0.9855, train_f1: 0.9776, val_loss: 0.0596, val_acc: 0.9805, val_fi: 0.9701
# 1fold, epoch: 8, model: gender, train_loss: 0.1731, train_acc: 0.9334, train_f1: 0.9295, val_loss: 0.3029, val_acc: 0.8767, val_fi: 0.8653
# 1fold, epoch: 8, model: age, train_loss: 0.3411, train_acc: 0.8641, train_f1: 0.7284, val_loss: 0.4635, val_acc: 0.8095, val_fi: 0.7155
# 1fold, epoch: 8, 학습시간: 288.51808285713196
#
# 1fold, epoch: 9, model: label, train_loss: 0.3347, train_acc: 0.8798, train_f1: 0.7620, val_loss: 1.3921, val_acc: 0.5919, val_fi: 0.5104
# 1fold, epoch: 9, model: mask, train_loss: 0.0362, train_acc: 0.9893, train_f1: 0.9828, val_loss: 0.0865, val_acc: 0.9735, val_fi: 0.9557
# 1fold, epoch: 9, model: gender, train_loss: 0.1426, train_acc: 0.9454, train_f1: 0.9418, val_loss: 0.1370, val_acc: 0.9468, val_fi: 0.9427
# 1fold, epoch: 9, model: age, train_loss: 0.3158, train_acc: 0.8733, train_f1: 0.7388, val_loss: 0.3493, val_acc: 0.8638, val_fi: 0.7629
# 1fold, epoch: 9, 학습시간: 288.24283361434937
#
# 1fold, epoch: 10, model: label, train_loss: 0.2772, train_acc: 0.9006, train_f1: 0.7973, val_loss: 0.6188, val_acc: 0.7986, val_fi: 0.6685
# 1fold, epoch: 10, model: mask, train_loss: 0.0344, train_acc: 0.9902, train_f1: 0.9843, val_loss: 0.0401, val_acc: 0.9907, val_fi: 0.9859
# 1fold, epoch: 10, model: gender, train_loss: 0.1204, train_acc: 0.9537, train_f1: 0.9508, val_loss: 0.2755, val_acc: 0.8886, val_fi: 0.8743
# 1fold, epoch: 10, model: age, train_loss: 0.2857, train_acc: 0.8847, train_f1: 0.7694, val_loss: 0.3349, val_acc: 0.8690, val_fi: 0.7544
# 1fold, epoch: 10, 학습시간: 288.6916913986206
#
# 1fold 훈련 시간: 2901.9568412303925
# 2fold, epoch: 1, model: label, train_loss: 2.1292, train_acc: 0.3477, train_f1: 0.0970, val_loss: 2.2601, val_acc: 0.3429, val_fi: 0.1206
# 2fold, epoch: 1, model: mask, train_loss: 0.7767, train_acc: 0.7150, train_f1: 0.3445, val_loss: 0.7214, val_acc: 0.7312, val_fi: 0.3940
# 2fold, epoch: 1, model: gender, train_loss: 0.6497, train_acc: 0.6592, train_f1: 0.5632, val_loss: 0.7435, val_acc: 0.5374, val_fi: 0.5343
# 2fold, epoch: 1, model: age, train_loss: 0.7999, train_acc: 0.6518, train_f1: 0.4425, val_loss: 0.7016, val_acc: 0.7040, val_fi: 0.4861
# 2fold, epoch: 1, 학습시간: 288.7580568790436
#
# 2fold, epoch: 2, model: label, train_loss: 1.4922, train_acc: 0.5258, train_f1: 0.2545, val_loss: 1.8356, val_acc: 0.3952, val_fi: 0.2227
# 2fold, epoch: 2, model: mask, train_loss: 0.4917, train_acc: 0.8164, train_f1: 0.6070, val_loss: 0.4224, val_acc: 0.8512, val_fi: 0.7928
# 2fold, epoch: 2, model: gender, train_loss: 0.4849, train_acc: 0.7684, train_f1: 0.7527, val_loss: 0.7188, val_acc: 0.5718, val_fi: 0.5597
# 2fold, epoch: 2, model: age, train_loss: 0.5610, train_acc: 0.7761, train_f1: 0.5367, val_loss: 0.5436, val_acc: 0.7814, val_fi: 0.5395
# 2fold, epoch: 2, 학습시간: 290.2560136318207
#
# 2fold, epoch: 3, model: label, train_loss: 1.0633, train_acc: 0.6394, train_f1: 0.4166, val_loss: 1.2745, val_acc: 0.5797, val_fi: 0.4137
# 2fold, epoch: 3, model: mask, train_loss: 0.2129, train_acc: 0.9268, train_f1: 0.8818, val_loss: 0.1700, val_acc: 0.9425, val_fi: 0.9022
# 2fold, epoch: 3, model: gender, train_loss: 0.3776, train_acc: 0.8346, train_f1: 0.8249, val_loss: 0.4370, val_acc: 0.8194, val_fi: 0.8154
# 2fold, epoch: 3, model: age, train_loss: 0.5235, train_acc: 0.7894, train_f1: 0.5505, val_loss: 0.5873, val_acc: 0.7530, val_fi: 0.5201
# 2fold, epoch: 3, 학습시간: 289.2487676143646
#
# 2fold, epoch: 4, model: label, train_loss: 0.7734, train_acc: 0.7391, train_f1: 0.5562, val_loss: 1.7544, val_acc: 0.4448, val_fi: 0.3417
# 2fold, epoch: 4, model: mask, train_loss: 0.1412, train_acc: 0.9544, train_f1: 0.9312, val_loss: 0.2578, val_acc: 0.9292, val_fi: 0.8722
# 2fold, epoch: 4, model: gender, train_loss: 0.2861, train_acc: 0.8838, train_f1: 0.8768, val_loss: 0.4193, val_acc: 0.8532, val_fi: 0.8347
# 2fold, epoch: 4, model: age, train_loss: 0.4673, train_acc: 0.8076, train_f1: 0.5749, val_loss: 0.4435, val_acc: 0.8221, val_fi: 0.5700
# 2fold, epoch: 4, 학습시간: 288.63897228240967
#
# 2fold, epoch: 5, model: label, train_loss: 0.6367, train_acc: 0.7787, train_f1: 0.6095, val_loss: 0.9893, val_acc: 0.6733, val_fi: 0.5688
# 2fold, epoch: 5, model: mask, train_loss: 0.0852, train_acc: 0.9732, train_f1: 0.9598, val_loss: 0.0857, val_acc: 0.9752, val_fi: 0.9623
# 2fold, epoch: 5, model: gender, train_loss: 0.2144, train_acc: 0.9139, train_f1: 0.9088, val_loss: 0.2050, val_acc: 0.9239, val_fi: 0.9183
# 2fold, epoch: 5, model: age, train_loss: 0.4359, train_acc: 0.8244, train_f1: 0.6185, val_loss: 0.4118, val_acc: 0.8317, val_fi: 0.6515
# 2fold, epoch: 5, 학습시간: 287.00244665145874
#
# 2fold, epoch: 6, model: label, train_loss: 0.5426, train_acc: 0.8103, train_f1: 0.6518, val_loss: 0.8945, val_acc: 0.6819, val_fi: 0.5304
# 2fold, epoch: 6, model: mask, train_loss: 0.0856, train_acc: 0.9730, train_f1: 0.9581, val_loss: 0.1077, val_acc: 0.9712, val_fi: 0.9528
# 2fold, epoch: 6, model: gender, train_loss: 0.1850, train_acc: 0.9281, train_f1: 0.9240, val_loss: 0.5104, val_acc: 0.8039, val_fi: 0.8017
# 2fold, epoch: 6, model: age, train_loss: 0.4067, train_acc: 0.8350, train_f1: 0.6466, val_loss: 0.4224, val_acc: 0.8284, val_fi: 0.6634
# 2fold, epoch: 6, 학습시간: 291.82454776763916
#
# 2fold, epoch: 7, model: label, train_loss: 0.4570, train_acc: 0.8347, train_f1: 0.6882, val_loss: 0.8955, val_acc: 0.7209, val_fi: 0.6038
# 2fold, epoch: 7, model: mask, train_loss: 0.0712, train_acc: 0.9767, train_f1: 0.9646, val_loss: 0.2012, val_acc: 0.9474, val_fi: 0.9102
# 2fold, epoch: 7, model: gender, train_loss: 0.1606, train_acc: 0.9387, train_f1: 0.9349, val_loss: 0.2418, val_acc: 0.9034, val_fi: 0.8994
# 2fold, epoch: 7, model: age, train_loss: 0.3817, train_acc: 0.8428, train_f1: 0.6791, val_loss: 0.4730, val_acc: 0.8108, val_fi: 0.6453
# 2fold, epoch: 7, 학습시간: 287.9494547843933
#
# 2fold, epoch: 8, model: label, train_loss: 0.4067, train_acc: 0.8535, train_f1: 0.7189, val_loss: 0.7485, val_acc: 0.7526, val_fi: 0.6639
# 2fold, epoch: 8, model: mask, train_loss: 0.0620, train_acc: 0.9805, train_f1: 0.9703, val_loss: 0.1999, val_acc: 0.9329, val_fi: 0.9006
# 2fold, epoch: 8, model: gender, train_loss: 0.1202, train_acc: 0.9553, train_f1: 0.9522, val_loss: 0.1507, val_acc: 0.9461, val_fi: 0.9407
# 2fold, epoch: 8, model: age, train_loss: 0.3733, train_acc: 0.8500, train_f1: 0.7048, val_loss: 0.5587, val_acc: 0.8016, val_fi: 0.5839
# 2fold, epoch: 8, 학습시간: 290.4932281970978
#
# 2fold, epoch: 9, model: label, train_loss: 0.3442, train_acc: 0.8731, train_f1: 0.7427, val_loss: 1.0564, val_acc: 0.6607, val_fi: 0.5244
# 2fold, epoch: 9, model: mask, train_loss: 0.0502, train_acc: 0.9847, train_f1: 0.9760, val_loss: 0.2024, val_acc: 0.9358, val_fi: 0.8884
# 2fold, epoch: 9, model: gender, train_loss: 0.1150, train_acc: 0.9554, train_f1: 0.9529, val_loss: 0.5433, val_acc: 0.8479, val_fi: 0.8245
# 2fold, epoch: 9, model: age, train_loss: 0.3437, train_acc: 0.8609, train_f1: 0.7254, val_loss: 0.4354, val_acc: 0.8370, val_fi: 0.5939
# 2fold, epoch: 9, 학습시간: 289.45091676712036
#
# 2fold, epoch: 10, model: label, train_loss: 0.2961, train_acc: 0.8914, train_f1: 0.7620, val_loss: 1.1318, val_acc: 0.7047, val_fi: 0.6431
# 2fold, epoch: 10, model: mask, train_loss: 0.0469, train_acc: 0.9860, train_f1: 0.9784, val_loss: 0.0763, val_acc: 0.9805, val_fi: 0.9714
# 2fold, epoch: 10, model: gender, train_loss: 0.1006, train_acc: 0.9630, train_f1: 0.9608, val_loss: 0.3771, val_acc: 0.8942, val_fi: 0.8808
# 2fold, epoch: 10, model: age, train_loss: 0.3171, train_acc: 0.8728, train_f1: 0.7473, val_loss: 0.4606, val_acc: 0.8105, val_fi: 0.7403
# 2fold, epoch: 10, 학습시간: 287.93934965133667
#
# 2fold 훈련 시간: 2899.14390707016
# 3fold, epoch: 1, model: label, train_loss: 2.1456, train_acc: 0.3305, train_f1: 0.1022, val_loss: 2.1336, val_acc: 0.3406, val_fi: 0.1322
# 3fold, epoch: 1, model: mask, train_loss: 0.7853, train_acc: 0.7161, train_f1: 0.3627, val_loss: 0.7441, val_acc: 0.7285, val_fi: 0.4682
# 3fold, epoch: 1, model: gender, train_loss: 0.6467, train_acc: 0.6392, train_f1: 0.5515, val_loss: 0.5462, val_acc: 0.7381, val_fi: 0.7317
# 3fold, epoch: 1, model: age, train_loss: 0.7125, train_acc: 0.7068, train_f1: 0.4872, val_loss: 0.8383, val_acc: 0.6703, val_fi: 0.4495
# 3fold, epoch: 1, 학습시간: 288.4165909290314
#
# 3fold, epoch: 2, model: label, train_loss: 1.4907, train_acc: 0.5219, train_f1: 0.2586, val_loss: 2.3664, val_acc: 0.3634, val_fi: 0.2405
# 3fold, epoch: 2, model: mask, train_loss: 0.4108, train_acc: 0.8466, train_f1: 0.7001, val_loss: 0.2501, val_acc: 0.9137, val_fi: 0.8720
# 3fold, epoch: 2, model: gender, train_loss: 0.4866, train_acc: 0.7690, train_f1: 0.7533, val_loss: 0.5063, val_acc: 0.7629, val_fi: 0.7318
# 3fold, epoch: 2, model: age, train_loss: 0.5513, train_acc: 0.7712, train_f1: 0.5325, val_loss: 0.8436, val_acc: 0.7030, val_fi: 0.4732
# 3fold, epoch: 2, 학습시간: 288.4847948551178
#
# 3fold, epoch: 3, model: label, train_loss: 1.0282, train_acc: 0.6583, train_f1: 0.4534, val_loss: 1.2232, val_acc: 0.5794, val_fi: 0.4424
# 3fold, epoch: 3, model: mask, train_loss: 0.1794, train_acc: 0.9390, train_f1: 0.9083, val_loss: 0.1674, val_acc: 0.9497, val_fi: 0.9255
# 3fold, epoch: 3, model: gender, train_loss: 0.3963, train_acc: 0.8253, train_f1: 0.8134, val_loss: 0.3665, val_acc: 0.8403, val_fi: 0.8367
# 3fold, epoch: 3, model: age, train_loss: 0.4834, train_acc: 0.8018, train_f1: 0.5603, val_loss: 0.5294, val_acc: 0.7784, val_fi: 0.6231
# 3fold, epoch: 3, 학습시간: 288.0051121711731
#
# 3fold, epoch: 4, model: label, train_loss: 0.7801, train_acc: 0.7364, train_f1: 0.5625, val_loss: 1.0178, val_acc: 0.6716, val_fi: 0.4198
# 3fold, epoch: 4, model: mask, train_loss: 0.1120, train_acc: 0.9617, train_f1: 0.9424, val_loss: 0.3954, val_acc: 0.8690, val_fi: 0.7674
# 3fold, epoch: 4, model: gender, train_loss: 0.3151, train_acc: 0.8676, train_f1: 0.8600, val_loss: 0.3110, val_acc: 0.8727, val_fi: 0.8607
# 3fold, epoch: 4, model: age, train_loss: 0.4520, train_acc: 0.8117, train_f1: 0.5818, val_loss: 0.4755, val_acc: 0.8072, val_fi: 0.5844
# 3fold, epoch: 4, 학습시간: 289.100378036499
#
# 3fold, epoch: 5, model: label, train_loss: 0.6666, train_acc: 0.7669, train_f1: 0.5960, val_loss: 1.0402, val_acc: 0.6472, val_fi: 0.4767
# 3fold, epoch: 5, model: mask, train_loss: 0.0851, train_acc: 0.9715, train_f1: 0.9560, val_loss: 0.6456, val_acc: 0.8085, val_fi: 0.7958
# 3fold, epoch: 5, model: gender, train_loss: 0.2559, train_acc: 0.8934, train_f1: 0.8877, val_loss: 0.3084, val_acc: 0.8624, val_fi: 0.8577
# 3fold, epoch: 5, model: age, train_loss: 0.4246, train_acc: 0.8242, train_f1: 0.6152, val_loss: 0.3939, val_acc: 0.8406, val_fi: 0.6938
# 3fold, epoch: 5, 학습시간: 287.9812762737274
#
# 3fold, epoch: 6, model: label, train_loss: 0.5496, train_acc: 0.8056, train_f1: 0.6555, val_loss: 2.1007, val_acc: 0.4894, val_fi: 0.3844
# 3fold, epoch: 6, model: mask, train_loss: 0.0626, train_acc: 0.9809, train_f1: 0.9709, val_loss: 0.0855, val_acc: 0.9755, val_fi: 0.9619
# 3fold, epoch: 6, model: gender, train_loss: 0.2229, train_acc: 0.9103, train_f1: 0.9049, val_loss: 0.5634, val_acc: 0.8228, val_fi: 0.7913
# 3fold, epoch: 6, model: age, train_loss: 0.3838, train_acc: 0.8439, train_f1: 0.6556, val_loss: 0.3904, val_acc: 0.8485, val_fi: 0.7052
# 3fold, epoch: 6, 학습시간: 287.6793704032898
#
# 3fold, epoch: 7, model: label, train_loss: 0.4733, train_acc: 0.8302, train_f1: 0.6722, val_loss: 1.1461, val_acc: 0.6746, val_fi: 0.5244
# 3fold, epoch: 7, model: mask, train_loss: 0.0585, train_acc: 0.9821, train_f1: 0.9723, val_loss: 0.2631, val_acc: 0.9177, val_fi: 0.8595
# 3fold, epoch: 7, model: gender, train_loss: 0.1921, train_acc: 0.9244, train_f1: 0.9195, val_loss: 0.2935, val_acc: 0.8833, val_fi: 0.8722
# 3fold, epoch: 7, model: age, train_loss: 0.3468, train_acc: 0.8600, train_f1: 0.7087, val_loss: 0.6522, val_acc: 0.8247, val_fi: 0.6460
# 3fold, epoch: 7, 학습시간: 287.7362070083618
#
# 3fold, epoch: 8, model: label, train_loss: 0.4314, train_acc: 0.8461, train_f1: 0.7118, val_loss: 0.8997, val_acc: 0.6852, val_fi: 0.5562
# 3fold, epoch: 8, model: mask, train_loss: 0.0530, train_acc: 0.9843, train_f1: 0.9758, val_loss: 0.0988, val_acc: 0.9709, val_fi: 0.9578
# 3fold, epoch: 8, model: gender, train_loss: 0.1570, train_acc: 0.9402, train_f1: 0.9367, val_loss: 0.2125, val_acc: 0.9084, val_fi: 0.9056
# 3fold, epoch: 8, model: age, train_loss: 0.3477, train_acc: 0.8565, train_f1: 0.7068, val_loss: 1.1715, val_acc: 0.5923, val_fi: 0.4619
# 3fold, epoch: 8, 학습시간: 289.4500479698181
#
# 3fold, epoch: 9, model: label, train_loss: 0.3546, train_acc: 0.8711, train_f1: 0.7450, val_loss: 1.0914, val_acc: 0.6171, val_fi: 0.5400
# 3fold, epoch: 9, model: mask, train_loss: 0.0483, train_acc: 0.9850, train_f1: 0.9778, val_loss: 0.0880, val_acc: 0.9732, val_fi: 0.9621
# 3fold, epoch: 9, model: gender, train_loss: 0.1229, train_acc: 0.9521, train_f1: 0.9492, val_loss: 0.1635, val_acc: 0.9352, val_fi: 0.9329
# 3fold, epoch: 9, model: age, train_loss: 0.3206, train_acc: 0.8717, train_f1: 0.7304, val_loss: 0.4258, val_acc: 0.8171, val_fi: 0.7353
# 3fold, epoch: 9, 학습시간: 289.3050925731659
#
# 3fold, epoch: 10, model: label, train_loss: 0.3135, train_acc: 0.8852, train_f1: 0.7869, val_loss: 0.4233, val_acc: 0.8571, val_fi: 0.6796
# 3fold, epoch: 10, model: mask, train_loss: 0.0349, train_acc: 0.9892, train_f1: 0.9841, val_loss: 0.0748, val_acc: 0.9769, val_fi: 0.9622
# 3fold, epoch: 10, model: gender, train_loss: 0.1124, train_acc: 0.9578, train_f1: 0.9555, val_loss: 0.1361, val_acc: 0.9448, val_fi: 0.9408
# 3fold, epoch: 10, model: age, train_loss: 0.3013, train_acc: 0.8767, train_f1: 0.7652, val_loss: 0.3344, val_acc: 0.8697, val_fi: 0.7625
# 3fold, epoch: 10, 학습시간: 288.1240932941437
#
# 3fold 훈련 시간: 2893.2627503871918
# 4fold, epoch: 1, model: label, train_loss: 2.0577, train_acc: 0.3646, train_f1: 0.1142, val_loss: 2.3323, val_acc: 0.3201, val_fi: 0.1529
# 4fold, epoch: 1, model: mask, train_loss: 0.7165, train_acc: 0.7331, train_f1: 0.4167, val_loss: 1.6103, val_acc: 0.5622, val_fi: 0.3740
# 4fold, epoch: 1, model: gender, train_loss: 0.6705, train_acc: 0.6397, train_f1: 0.5217, val_loss: 0.6051, val_acc: 0.6766, val_fi: 0.6069
# 4fold, epoch: 1, model: age, train_loss: 0.7649, train_acc: 0.6785, train_f1: 0.4592, val_loss: 0.8566, val_acc: 0.6776, val_fi: 0.4595
# 4fold, epoch: 1, 학습시간: 294.856981754303
#
# 4fold, epoch: 2, model: label, train_loss: 1.3979, train_acc: 0.5503, train_f1: 0.2850, val_loss: 1.9562, val_acc: 0.4732, val_fi: 0.2043
# 4fold, epoch: 2, model: mask, train_loss: 0.3400, train_acc: 0.8727, train_f1: 0.7674, val_loss: 0.2544, val_acc: 0.9127, val_fi: 0.8587
# 4fold, epoch: 2, model: gender, train_loss: 0.4851, train_acc: 0.7726, train_f1: 0.7560, val_loss: 0.7453, val_acc: 0.7044, val_fi: 0.6556
# 4fold, epoch: 2, model: age, train_loss: 0.5517, train_acc: 0.7753, train_f1: 0.5487, val_loss: 1.7359, val_acc: 0.4792, val_fi: 0.2491
# 4fold, epoch: 2, 학습시간: 291.431517124176
#
# 4fold, epoch: 3, model: label, train_loss: 0.9520, train_acc: 0.6825, train_f1: 0.4761, val_loss: 1.7778, val_acc: 0.4788, val_fi: 0.2885
# 4fold, epoch: 3, model: mask, train_loss: 0.1771, train_acc: 0.9391, train_f1: 0.9070, val_loss: 0.1449, val_acc: 0.9514, val_fi: 0.9257
# 4fold, epoch: 3, model: gender, train_loss: 0.3799, train_acc: 0.8329, train_f1: 0.8232, val_loss: 1.0834, val_acc: 0.6931, val_fi: 0.5957
# 4fold, epoch: 3, model: age, train_loss: 0.5008, train_acc: 0.7970, train_f1: 0.5901, val_loss: 0.6740, val_acc: 0.7226, val_fi: 0.5915
# 4fold, epoch: 3, 학습시간: 292.10889315605164
#
# 4fold, epoch: 4, model: label, train_loss: 0.7311, train_acc: 0.7509, train_f1: 0.5715, val_loss: 1.9904, val_acc: 0.4709, val_fi: 0.3561
# 4fold, epoch: 4, model: mask, train_loss: 0.1296, train_acc: 0.9576, train_f1: 0.9356, val_loss: 0.1689, val_acc: 0.9438, val_fi: 0.9185
# 4fold, epoch: 4, model: gender, train_loss: 0.3003, train_acc: 0.8755, train_f1: 0.8675, val_loss: 0.5022, val_acc: 0.8277, val_fi: 0.8116
# 4fold, epoch: 4, model: age, train_loss: 0.4518, train_acc: 0.8167, train_f1: 0.6200, val_loss: 0.6645, val_acc: 0.7312, val_fi: 0.6281
# 4fold, epoch: 4, 학습시간: 288.8084511756897
#
# 4fold, epoch: 5, model: label, train_loss: 0.5839, train_acc: 0.7982, train_f1: 0.6263, val_loss: 0.6876, val_acc: 0.7768, val_fi: 0.6144
# 4fold, epoch: 5, model: mask, train_loss: 0.0889, train_acc: 0.9717, train_f1: 0.9570, val_loss: 0.1111, val_acc: 0.9669, val_fi: 0.9507
# 4fold, epoch: 5, model: gender, train_loss: 0.2683, train_acc: 0.8906, train_f1: 0.8842, val_loss: 0.3052, val_acc: 0.8862, val_fi: 0.8741
# 4fold, epoch: 5, model: age, train_loss: 0.4189, train_acc: 0.8288, train_f1: 0.6500, val_loss: 1.0808, val_acc: 0.5605, val_fi: 0.4880
# 4fold, epoch: 5, 학습시간: 293.09726548194885
#
# 4fold, epoch: 6, model: label, train_loss: 0.5280, train_acc: 0.8148, train_f1: 0.6519, val_loss: 0.7368, val_acc: 0.7358, val_fi: 0.5963
# 4fold, epoch: 6, model: mask, train_loss: 0.0705, train_acc: 0.9783, train_f1: 0.9668, val_loss: 0.1079, val_acc: 0.9640, val_fi: 0.9449
# 4fold, epoch: 6, model: gender, train_loss: 0.2161, train_acc: 0.9156, train_f1: 0.9105, val_loss: 0.2789, val_acc: 0.8882, val_fi: 0.8843
# 4fold, epoch: 6, model: age, train_loss: 0.3949, train_acc: 0.8426, train_f1: 0.6777, val_loss: 0.5092, val_acc: 0.7884, val_fi: 0.6342
# 4fold, epoch: 6, 학습시간: 291.72974491119385
#
# 4fold, epoch: 7, model: label, train_loss: 0.4557, train_acc: 0.8393, train_f1: 0.6989, val_loss: 0.5284, val_acc: 0.8198, val_fi: 0.6636
# 4fold, epoch: 7, model: mask, train_loss: 0.0537, train_acc: 0.9831, train_f1: 0.9748, val_loss: 0.0647, val_acc: 0.9818, val_fi: 0.9698
# 4fold, epoch: 7, model: gender, train_loss: 0.1882, train_acc: 0.9262, train_f1: 0.9220, val_loss: 0.3255, val_acc: 0.8853, val_fi: 0.8729
# 4fold, epoch: 7, model: age, train_loss: 0.3715, train_acc: 0.8472, train_f1: 0.6953, val_loss: 0.4043, val_acc: 0.8290, val_fi: 0.7235
# 4fold, epoch: 7, 학습시간: 288.0990753173828
#
# 4fold, epoch: 8, model: label, train_loss: 0.3768, train_acc: 0.8667, train_f1: 0.7256, val_loss: 0.5547, val_acc: 0.7950, val_fi: 0.6695
# 4fold, epoch: 8, model: mask, train_loss: 0.0506, train_acc: 0.9834, train_f1: 0.9734, val_loss: 0.0755, val_acc: 0.9772, val_fi: 0.9657
# 4fold, epoch: 8, model: gender, train_loss: 0.1556, train_acc: 0.9396, train_f1: 0.9359, val_loss: 0.8560, val_acc: 0.7702, val_fi: 0.7093
# 4fold, epoch: 8, model: age, train_loss: 0.3417, train_acc: 0.8619, train_f1: 0.7180, val_loss: 0.3386, val_acc: 0.8654, val_fi: 0.7569
# 4fold, epoch: 8, 학습시간: 289.15943908691406
#
# 4fold, epoch: 9, model: label, train_loss: 0.3292, train_acc: 0.8793, train_f1: 0.7676, val_loss: 1.0370, val_acc: 0.6802, val_fi: 0.5592
# 4fold, epoch: 9, model: mask, train_loss: 0.0456, train_acc: 0.9866, train_f1: 0.9800, val_loss: 0.0887, val_acc: 0.9719, val_fi: 0.9514
# 4fold, epoch: 9, model: gender, train_loss: 0.1397, train_acc: 0.9491, train_f1: 0.9461, val_loss: 0.2119, val_acc: 0.9193, val_fi: 0.9161
# 4fold, epoch: 9, model: age, train_loss: 0.3122, train_acc: 0.8759, train_f1: 0.7507, val_loss: 0.3327, val_acc: 0.8681, val_fi: 0.7513
# 4fold, epoch: 9, 학습시간: 289.02963376045227
#
# 4fold, epoch: 10, model: label, train_loss: 0.2956, train_acc: 0.8915, train_f1: 0.7854, val_loss: 0.4084, val_acc: 0.8578, val_fi: 0.7152
# 4fold, epoch: 10, model: mask, train_loss: 0.0319, train_acc: 0.9912, train_f1: 0.9864, val_loss: 0.1096, val_acc: 0.9653, val_fi: 0.9517
# 4fold, epoch: 10, model: gender, train_loss: 0.1316, train_acc: 0.9517, train_f1: 0.9491, val_loss: 0.1370, val_acc: 0.9444, val_fi: 0.9424
# 4fold, epoch: 10, model: age, train_loss: 0.3016, train_acc: 0.8785, train_f1: 0.7625, val_loss: 0.3699, val_acc: 0.8476, val_fi: 0.7648
# 4fold, epoch: 10, 학습시간: 289.03921842575073
#
# 4fold 훈련 시간: 2916.0010290145874
# 5fold, epoch: 1, model: label, train_loss: 2.2081, train_acc: 0.3137, train_f1: 0.0823, val_loss: 2.2136, val_acc: 0.3353, val_fi: 0.1020
# 5fold, epoch: 1, model: mask, train_loss: 0.7756, train_acc: 0.7208, train_f1: 0.3571, val_loss: 0.7711, val_acc: 0.7001, val_fi: 0.4365
# 5fold, epoch: 1, model: gender, train_loss: 0.6679, train_acc: 0.6517, train_f1: 0.5426, val_loss: 0.7132, val_acc: 0.5939, val_fi: 0.5898
# 5fold, epoch: 1, model: age, train_loss: 0.7119, train_acc: 0.7141, train_f1: 0.4978, val_loss: 1.5759, val_acc: 0.4487, val_fi: 0.2720
# 5fold, epoch: 1, 학습시간: 288.17974066734314
#
# 5fold, epoch: 2, model: label, train_loss: 1.6052, train_acc: 0.4858, train_f1: 0.2295, val_loss: 3.4546, val_acc: 0.2490, val_fi: 0.1209
# 5fold, epoch: 2, model: mask, train_loss: 0.4966, train_acc: 0.8125, train_f1: 0.5967, val_loss: 0.5195, val_acc: 0.8102, val_fi: 0.5498
# 5fold, epoch: 2, model: gender, train_loss: 0.4855, train_acc: 0.7736, train_f1: 0.7577, val_loss: 0.7297, val_acc: 0.6300, val_fi: 0.5920
# 5fold, epoch: 2, model: age, train_loss: 0.5609, train_acc: 0.7737, train_f1: 0.5504, val_loss: 0.9101, val_acc: 0.6908, val_fi: 0.4646
# 5fold, epoch: 2, 학습시간: 289.2292618751526
#
# 5fold, epoch: 3, model: label, train_loss: 0.9985, train_acc: 0.6624, train_f1: 0.4635, val_loss: 1.5209, val_acc: 0.5903, val_fi: 0.2926
# 5fold, epoch: 3, model: mask, train_loss: 0.2217, train_acc: 0.9229, train_f1: 0.8765, val_loss: 0.2037, val_acc: 0.9269, val_fi: 0.8829
# 5fold, epoch: 3, model: gender, train_loss: 0.3994, train_acc: 0.8206, train_f1: 0.8093, val_loss: 0.3497, val_acc: 0.8492, val_fi: 0.8290
# 5fold, epoch: 3, model: age, train_loss: 0.4986, train_acc: 0.7953, train_f1: 0.5786, val_loss: 1.6232, val_acc: 0.4468, val_fi: 0.3540
# 5fold, epoch: 3, 학습시간: 289.3883249759674
#
# 5fold, epoch: 4, model: label, train_loss: 0.7166, train_acc: 0.7579, train_f1: 0.5788, val_loss: 1.0257, val_acc: 0.6524, val_fi: 0.4769
# 5fold, epoch: 4, model: mask, train_loss: 0.1303, train_acc: 0.9581, train_f1: 0.9357, val_loss: 0.2291, val_acc: 0.9223, val_fi: 0.8715
# 5fold, epoch: 4, model: gender, train_loss: 0.2994, train_acc: 0.8752, train_f1: 0.8679, val_loss: 2.9079, val_acc: 0.6627, val_fi: 0.5067
# 5fold, epoch: 4, model: age, train_loss: 0.4665, train_acc: 0.8112, train_f1: 0.6052, val_loss: 0.5297, val_acc: 0.7933, val_fi: 0.5494
# 5fold, epoch: 4, 학습시간: 287.73828649520874
#
# 5fold, epoch: 5, model: label, train_loss: 0.6363, train_acc: 0.7805, train_f1: 0.6212, val_loss: 0.6930, val_acc: 0.7569, val_fi: 0.5793
# 5fold, epoch: 5, model: mask, train_loss: 0.1087, train_acc: 0.9664, train_f1: 0.9506, val_loss: 0.1299, val_acc: 0.9521, val_fi: 0.9238
# 5fold, epoch: 5, model: gender, train_loss: 0.2674, train_acc: 0.8930, train_f1: 0.8862, val_loss: 0.2824, val_acc: 0.8813, val_fi: 0.8750
# 5fold, epoch: 5, model: age, train_loss: 0.4275, train_acc: 0.8271, train_f1: 0.6445, val_loss: 0.4417, val_acc: 0.8294, val_fi: 0.6302
# 5fold, epoch: 5, 학습시간: 291.62809014320374
#
# 5fold, epoch: 6, model: label, train_loss: 0.5464, train_acc: 0.8104, train_f1: 0.6650, val_loss: 0.7263, val_acc: 0.7487, val_fi: 0.5978
# 5fold, epoch: 6, model: mask, train_loss: 0.0825, train_acc: 0.9737, train_f1: 0.9601, val_loss: 0.1717, val_acc: 0.9415, val_fi: 0.9191
# 5fold, epoch: 6, model: gender, train_loss: 0.2103, train_acc: 0.9163, train_f1: 0.9114, val_loss: 0.2021, val_acc: 0.9259, val_fi: 0.9203
# 5fold, epoch: 6, model: age, train_loss: 0.3927, train_acc: 0.8409, train_f1: 0.6724, val_loss: 0.5693, val_acc: 0.7784, val_fi: 0.5771
# 5fold, epoch: 6, 학습시간: 289.7110393047333
#
# 5fold, epoch: 7, model: label, train_loss: 0.4313, train_acc: 0.8442, train_f1: 0.7032, val_loss: 0.5990, val_acc: 0.8069, val_fi: 0.6732
# 5fold, epoch: 7, model: mask, train_loss: 0.0651, train_acc: 0.9795, train_f1: 0.9687, val_loss: 0.1671, val_acc: 0.9355, val_fi: 0.9148
# 5fold, epoch: 7, model: gender, train_loss: 0.1780, train_acc: 0.9324, train_f1: 0.9285, val_loss: 0.2440, val_acc: 0.8958, val_fi: 0.8880
# 5fold, epoch: 7, model: age, train_loss: 0.3646, train_acc: 0.8552, train_f1: 0.7081, val_loss: 0.3890, val_acc: 0.8472, val_fi: 0.6780
# 5fold, epoch: 7, 학습시간: 289.3952555656433
#
# 5fold, epoch: 8, model: label, train_loss: 0.3838, train_acc: 0.8639, train_f1: 0.7459, val_loss: 0.8396, val_acc: 0.7331, val_fi: 0.5813
# 5fold, epoch: 8, model: mask, train_loss: 0.0588, train_acc: 0.9829, train_f1: 0.9730, val_loss: 0.0687, val_acc: 0.9798, val_fi: 0.9681
# 5fold, epoch: 8, model: gender, train_loss: 0.1586, train_acc: 0.9406, train_f1: 0.9370, val_loss: 0.2713, val_acc: 0.9061, val_fi: 0.8955
# 5fold, epoch: 8, model: age, train_loss: 0.3496, train_acc: 0.8595, train_f1: 0.7014, val_loss: 0.4320, val_acc: 0.8224, val_fi: 0.7022
# 5fold, epoch: 8, 학습시간: 288.9102714061737
#
# 5fold, epoch: 9, model: label, train_loss: 0.3220, train_acc: 0.8846, train_f1: 0.7772, val_loss: 0.6827, val_acc: 0.7698, val_fi: 0.5790
# 5fold, epoch: 9, model: mask, train_loss: 0.0467, train_acc: 0.9851, train_f1: 0.9768, val_loss: 0.0790, val_acc: 0.9772, val_fi: 0.9623
# 5fold, epoch: 9, model: gender, train_loss: 0.1315, train_acc: 0.9517, train_f1: 0.9489, val_loss: 0.5404, val_acc: 0.8032, val_fi: 0.8011
# 5fold, epoch: 9, model: age, train_loss: 0.3210, train_acc: 0.8720, train_f1: 0.7480, val_loss: 0.3873, val_acc: 0.8416, val_fi: 0.7127
# 5fold, epoch: 9, 학습시간: 291.83927631378174
#
# 5fold, epoch: 10, model: label, train_loss: 0.2817, train_acc: 0.8986, train_f1: 0.8060, val_loss: 0.5145, val_acc: 0.8115, val_fi: 0.6955
# 5fold, epoch: 10, model: mask, train_loss: 0.0533, train_acc: 0.9841, train_f1: 0.9763, val_loss: 0.0819, val_acc: 0.9719, val_fi: 0.9555
# 5fold, epoch: 10, model: gender, train_loss: 0.1172, train_acc: 0.9562, train_f1: 0.9537, val_loss: 0.1347, val_acc: 0.9497, val_fi: 0.9464
# 5fold, epoch: 10, model: age, train_loss: 0.2954, train_acc: 0.8821, train_f1: 0.7701, val_loss: 0.4170, val_acc: 0.8333, val_fi: 0.6997
# 5fold, epoch: 10, 학습시간: 290.58946681022644
#
# 5fold 훈련 시간: 2904.8756580352783
# 총 훈련 시간: 14515.24930357933

# %% [markdown]
# # 평가

# %%
'''

평가 및 예측

'''

skf = StratifiedKFold(n_splits = fold_num, random_state = seed, shuffle = True)

# 앙상블 데이터 저장용
train_oof = np.zeros((train_set.shape[0], 4))
test_oof = np.zeros((test_set.shape[0], 4))
submission_oof = np.zeros((submission.shape[0], 4))

# test 데이터 정의
test_dataset = CustomDataset(df = test_set, 
                            transform = transform, 
                            train = True)

test_loder = DataLoader(test_dataset,
                        batch_size = batch_size,
                        shuffle = False,)

test_label_oof = np.zeros((test_set.shape[0], 18))
test_mask_oof = np.zeros((test_set.shape[0], 3))
test_gender_oof = np.zeros((test_set.shape[0], 2))
test_age_oof = np.zeros((test_set.shape[0], 3))

# submission 데이터 정의
submission_dataset = CustomDataset(df = submission, 
                            transform = transform, 
                            train = False)

submission_loder = DataLoader(submission_dataset,
                        batch_size = batch_size,
                        shuffle = False,)

submission_label_oof = np.zeros((submission.shape[0], 18))
submission_mask_oof = np.zeros((submission.shape[0], 3))
submission_gender_oof = np.zeros((submission.shape[0], 2))
submission_age_oof = np.zeros((submission.shape[0], 3))

# 예측
for now_fold_num, (trn_idx, val_idx) in tqdm(enumerate(skf.split(train_set, train_set['label']))):
    val_df = train_set.iloc[val_idx, :]
    
    val_dataset = CustomDataset(df = val_df, 
                                transform = transform, 
                                train = True)
    
    val_loder = DataLoader(val_dataset,
                            batch_size = batch_size,
                            shuffle = False,)
    
    
    # 모델 로드
    label_model = ResNet(block = BasicBlock, num_blocks = [2, 2, 2, 2], num_classes = 18).to(device)
    label_model.load_state_dict(torch.load(model_dir + f'{now_fold_num + 1}fold_label_ResNet.pt', map_location = device))
    
    mask_model = ResNet(block = BasicBlock, num_blocks = [2, 2, 2, 2], num_classes = 3).to(device)
    mask_model.load_state_dict(torch.load(model_dir + f'{now_fold_num + 1}fold_mask_ResNet.pt', map_location = device))
    
    gender_model = ResNet(block = BasicBlock, num_blocks = [2, 2, 2, 2], num_classes = 2).to(device)
    gender_model.load_state_dict(torch.load(model_dir + f'{now_fold_num + 1}fold_gender_ResNet.pt', map_location = device))
    
    age_model = ResNet(block = BasicBlock, num_blocks = [2, 2, 2, 2], num_classes = 3).to(device)
    age_model.load_state_dict(torch.load(model_dir + f'{now_fold_num + 1}fold_age_ResNet.pt', map_location = device))    
    
    # train_oof
    label_pred_li, mask_pred_li, gender_pred_li, age_pred_li = [], [], [], []
    with torch.no_grad():
        for images, _, _, _, _ in val_loder:
            images = images.to(device)
            
            label = label_model(images).argmax(dim=-1)
            mask = mask_model(images).argmax(dim=-1)
            gender = gender_model(images).argmax(dim=-1)
            age = age_model(images).argmax(dim=-1)
            
            label_pred_li.extend(label.cpu().numpy())
            mask_pred_li.extend(mask.cpu().numpy())
            gender_pred_li.extend(gender.cpu().numpy())
            age_pred_li.extend(age.cpu().numpy())
    
    train_oof[val_idx, 0] = label_pred_li
    train_oof[val_idx, 1] = mask_pred_li
    train_oof[val_idx, 2] = gender_pred_li
    train_oof[val_idx, 3] = age_pred_li
    
    # test_oof
    label_pred_li, mask_pred_li, gender_pred_li, age_pred_li = [], [], [], []
    with torch.no_grad():
        for images, _, _, _, _ in test_loder:
            images = images.to(device)
            
            label = label_model(images).softmax(1)
            mask = mask_model(images).softmax(1)
            gender = gender_model(images).softmax(1)
            age = age_model(images).softmax(1)
            
            label_pred_li.append(label.cpu().numpy())
            mask_pred_li.append(mask.cpu().numpy())
            gender_pred_li.append(gender.cpu().numpy())
            age_pred_li.append(age.cpu().numpy())

    test_label_oof += np.concatenate(label_pred_li) / fold_num
    test_mask_oof += np.concatenate(mask_pred_li)/ fold_num
    test_gender_oof +=np.concatenate(gender_pred_li) / fold_num
    test_age_oof += np.concatenate(age_pred_li) / fold_num
    
    # submission_oof
    label_pred_li, mask_pred_li, gender_pred_li, age_pred_li = [], [], [], []
    with torch.no_grad():
        for images in submission_loder:
            images = images.to(device)
            
            label = label_model(images).softmax(1)
            mask = mask_model(images).softmax(1)
            gender = gender_model(images).softmax(1)
            age = age_model(images).softmax(1)
            
            label_pred_li.append(label.cpu().numpy())
            mask_pred_li.append(mask.cpu().numpy())
            gender_pred_li.append(gender.cpu().numpy())
            age_pred_li.append(age.cpu().numpy())

    submission_label_oof += np.concatenate(label_pred_li) / fold_num
    submission_mask_oof += np.concatenate(mask_pred_li)/ fold_num
    submission_gender_oof +=np.concatenate(gender_pred_li) / fold_num
    submission_age_oof += np.concatenate(age_pred_li) / fold_num

test_oof[:, 0] = test_label_oof.argmax(1).tolist()
test_oof[:, 1] = test_mask_oof.argmax(1).tolist()
test_oof[:, 2] = test_gender_oof.argmax(1).tolist()
test_oof[:, 3] = test_age_oof.argmax(1).tolist()

submission_oof[:, 0] = submission_label_oof.argmax(1).tolist()
submission_oof[:, 1] = submission_mask_oof.argmax(1).tolist()
submission_oof[:, 2] = submission_gender_oof.argmax(1).tolist()
submission_oof[:, 3] = submission_age_oof.argmax(1).tolist()
# Out:
# 5it [17:38, 211.72s/it]

# %%
col_li = ['label', 'mask', 'gender_group', 'age_group']

ensemble_train_df = pd.DataFrame(train_oof, columns = col_li).astype(int)
ensemble_train_df['ensemble_label'] = ensemble_train_df['mask'] * 6 + ensemble_train_df['gender_group'] * 3 + ensemble_train_df['age_group']

ensemble_test_df = pd.DataFrame(test_oof, columns = col_li).astype(int)
ensemble_test_df['ensemble_label'] = ensemble_test_df['mask'] * 6 + ensemble_test_df['gender_group'] * 3 + ensemble_test_df['age_group']

ensemble_submission_df = pd.DataFrame(submission_oof, columns = col_li)
ensemble_submission_df['ensemble_label'] = ensemble_submission_df['mask'] * 6 + ensemble_submission_df['gender_group'] * 3 + ensemble_submission_df['age_group']

# %%
'''

confusion_matrix and f1

'''

col_li = ['label', 'mask', 'gender_group', 'age_group', 'ensemble_label']

for col in col_li:
    if col != 'ensemble_label':
        train_y_true = train_set[col].values
        train_y_pred = ensemble_train_df[col].values
        
        test_y_true = test_set[col].values
        test_y_pred = ensemble_test_df[col].values
    
    else:
        train_y_true = train_set['label'].values
        train_y_pred = ensemble_train_df[col].values
        
        test_y_true = test_set['label'].values
        test_y_pred = ensemble_test_df[col].values        
    
    
    train_f1 = get_f1_score(y_true = train_y_true,  y_pred = train_y_pred)
    train_acc = get_acc_score(y_true = train_y_true, y_pred = train_y_pred)
    
    test_f1 = get_f1_score(y_true = test_y_true, y_pred = test_y_pred)
    test_acc = get_acc_score(y_true = test_y_true, y_pred = test_y_pred)
    
    train_confusion_matrix = pd.DataFrame((confusion_matrix(y_true = train_y_true, y_pred = train_y_pred)))
    test_confusion_matrix = pd.DataFrame((confusion_matrix(y_true = test_y_true, y_pred = test_y_pred)))
    
    print(f'{col} train confusion_matrix')
    display(train_confusion_matrix.style.background_gradient(cmap='YlOrRd', axis = 0))
    
    print(f'{col} test confusion_matrix')
    display(test_confusion_matrix.style.background_gradient(cmap='YlOrRd', axis = 0))
    
    print(f'train fi : {train_f1}, train acc: {train_acc}, test_f1 fi : {test_f1}, test acc: {test_acc} \n')
# Out:
# label train confusion_matrix
# <style  type="text/css" >
# #T_327ff2ee_93ef_11ec_a811_0242ac110002row0_col0,#T_327ff2ee_93ef_11ec_a811_0242ac110002row1_col1,#T_327ff2ee_93ef_11ec_a811_0242ac110002row2_col2,#T_327ff2ee_93ef_11ec_a811_0242ac110002row3_col3,#T_327ff2ee_93ef_11ec_a811_0242ac110002row4_col4,#T_327ff2ee_93ef_11ec_a811_0242ac110002row5_col5,#T_327ff2ee_93ef_11ec_a811_0242ac110002row6_col6,#T_327ff2ee_93ef_11ec_a811_0242ac110002row7_col7,#T_327ff2ee_93ef_11ec_a811_0242ac110002row8_col8,#T_327ff2ee_93ef_11ec_a811_0242ac110002row9_col9,#T_327ff2ee_93ef_11ec_a811_0242ac110002row10_col10,#T_327ff2ee_93ef_11ec_a811_0242ac110002row11_col11,#T_327ff2ee_93ef_11ec_a811_0242ac110002row12_col12,#T_327ff2ee_93ef_11ec_a811_0242ac110002row13_col13,#T_327ff2ee_93ef_11ec_a811_0242ac110002row14_col14,#T_327ff2ee_93ef_11ec_a811_0242ac110002row15_col15,#T_327ff2ee_93ef_11ec_a811_0242ac110002row16_col16,#T_327ff2ee_93ef_11ec_a811_0242ac110002row17_col17{
#             background-color:  #800026;
#             color:  #f1f1f1;
#         }#T_327ff2ee_93ef_11ec_a811_0242ac110002row0_col1,#T_327ff2ee_93ef_11ec_a811_0242ac110002row3_col0,#T_327ff2ee_93ef_11ec_a811_0242ac110002row9_col6,#T_327ff2ee_93ef_11ec_a811_0242ac110002row15_col12{
#             background-color:  #fff9be;
#             color:  #000000;
#         }#T_327ff2ee_93ef_11ec_a811_0242ac110002row0_col2,#T_327ff2ee_93ef_11ec_a811_0242ac110002row0_col4,#T_327ff2ee_93ef_11ec_a811_0242ac110002row0_col9,#T_327ff2ee_93ef_11ec_a811_0242ac110002row1_col3,#T_327ff2ee_93ef_11ec_a811_0242ac110002row3_col1,#T_327ff2ee_93ef_11ec_a811_0242ac110002row4_col0,#T_327ff2ee_93ef_11ec_a811_0242ac110002row6_col0,#T_327ff2ee_93ef_11ec_a811_0242ac110002row7_col1,#T_327ff2ee_93ef_11ec_a811_0242ac110002row7_col2,#T_327ff2ee_93ef_11ec_a811_0242ac110002row8_col2,#T_327ff2ee_93ef_11ec_a811_0242ac110002row9_col3,#T_327ff2ee_93ef_11ec_a811_0242ac110002row9_col7,#T_327ff2ee_93ef_11ec_a811_0242ac110002row12_col6,#T_327ff2ee_93ef_11ec_a811_0242ac110002row13_col15,#T_327ff2ee_93ef_11ec_a811_0242ac110002row14_col16{
#             background-color:  #fffecb;
#             color:  #000000;
#         }#T_327ff2ee_93ef_11ec_a811_0242ac110002row0_col3,#T_327ff2ee_93ef_11ec_a811_0242ac110002row0_col6,#T_327ff2ee_93ef_11ec_a811_0242ac110002row10_col6,#T_327ff2ee_93ef_11ec_a811_0242ac110002row17_col13{
#             background-color:  #fffdc8;
#             color:  #000000;
#         }#T_327ff2ee_93ef_11ec_a811_0242ac110002row0_col5,#T_327ff2ee_93ef_11ec_a811_0242ac110002row0_col7,#T_327ff2ee_93ef_11ec_a811_0242ac110002row0_col8,#T_327ff2ee_93ef_11ec_a811_0242ac110002row0_col10,#T_327ff2ee_93ef_11ec_a811_0242ac110002row0_col11,#T_327ff2ee_93ef_11ec_a811_0242ac110002row0_col12,#T_327ff2ee_93ef_11ec_a811_0242ac110002row0_col13,#T_327ff2ee_93ef_11ec_a811_0242ac110002row0_col14,#T_327ff2ee_93ef_11ec_a811_0242ac110002row0_col15,#T_327ff2ee_93ef_11ec_a811_0242ac110002row0_col16,#T_327ff2ee_93ef_11ec_a811_0242ac110002row0_col17,#T_327ff2ee_93ef_11ec_a811_0242ac110002row1_col6,#T_327ff2ee_93ef_11ec_a811_0242ac110002row1_col8,#T_327ff2ee_93ef_11ec_a811_0242ac110002row1_col9,#T_327ff2ee_93ef_11ec_a811_0242ac110002row1_col10,#T_327ff2ee_93ef_11ec_a811_0242ac110002row1_col11,#T_327ff2ee_93ef_11ec_a811_0242ac110002row1_col12,#T_327ff2ee_93ef_11ec_a811_0242ac110002row1_col13,#T_327ff2ee_93ef_11ec_a811_0242ac110002row1_col14,#T_327ff2ee_93ef_11ec_a811_0242ac110002row1_col15,#T_327ff2ee_93ef_11ec_a811_0242ac110002row1_col16,#T_327ff2ee_93ef_11ec_a811_0242ac110002row1_col17,#T_327ff2ee_93ef_11ec_a811_0242ac110002row2_col0,#T_327ff2ee_93ef_11ec_a811_0242ac110002row2_col3,#T_327ff2ee_93ef_11ec_a811_0242ac110002row2_col4,#T_327ff2ee_93ef_11ec_a811_0242ac110002row2_col6,#T_327ff2ee_93ef_11ec_a811_0242ac110002row2_col7,#T_327ff2ee_93ef_11ec_a811_0242ac110002row2_col9,#T_327ff2ee_93ef_11ec_a811_0242ac110002row2_col10,#T_327ff2ee_93ef_11ec_a811_0242ac110002row2_col11,#T_327ff2ee_93ef_11ec_a811_0242ac110002row2_col12,#T_327ff2ee_93ef_11ec_a811_0242ac110002row2_col13,#T_327ff2ee_93ef_11ec_a811_0242ac110002row2_col14,#T_327ff2ee_93ef_11ec_a811_0242ac110002row2_col15,#T_327ff2ee_93ef_11ec_a811_0242ac110002row2_col16,#T_327ff2ee_93ef_11ec_a811_0242ac110002row3_col2,#T_327ff2ee_93ef_11ec_a811_0242ac110002row3_col5,#T_327ff2ee_93ef_11ec_a811_0242ac110002row3_col6,#T_327ff2ee_93ef_11ec_a811_0242ac110002row3_col7,#T_327ff2ee_93ef_11ec_a811_0242ac110002row3_col8,#T_327ff2ee_93ef_11ec_a811_0242ac110002row3_col10,#T_327ff2ee_93ef_11ec_a811_0242ac110002row3_col11,#T_327ff2ee_93ef_11ec_a811_0242ac110002row3_col12,#T_327ff2ee_93ef_11ec_a811_0242ac110002row3_col13,#T_327ff2ee_93ef_11ec_a811_0242ac110002row3_col14,#T_327ff2ee_93ef_11ec_a811_0242ac110002row3_col16,#T_327ff2ee_93ef_11ec_a811_0242ac110002row3_col17,#T_327ff2ee_93ef_11ec_a811_0242ac110002row4_col2,#T_327ff2ee_93ef_11ec_a811_0242ac110002row4_col6,#T_327ff2ee_93ef_11ec_a811_0242ac110002row4_col7,#T_327ff2ee_93ef_11ec_a811_0242ac110002row4_col8,#T_327ff2ee_93ef_11ec_a811_0242ac110002row4_col9,#T_327ff2ee_93ef_11ec_a811_0242ac110002row4_col11,#T_327ff2ee_93ef_11ec_a811_0242ac110002row4_col12,#T_327ff2ee_93ef_11ec_a811_0242ac110002row4_col13,#T_327ff2ee_93ef_11ec_a811_0242ac110002row4_col14,#T_327ff2ee_93ef_11ec_a811_0242ac110002row4_col15,#T_327ff2ee_93ef_11ec_a811_0242ac110002row4_col16,#T_327ff2ee_93ef_11ec_a811_0242ac110002row4_col17,#T_327ff2ee_93ef_11ec_a811_0242ac110002row5_col0,#T_327ff2ee_93ef_11ec_a811_0242ac110002row5_col3,#T_327ff2ee_93ef_11ec_a811_0242ac110002row5_col6,#T_327ff2ee_93ef_11ec_a811_0242ac110002row5_col7,#T_327ff2ee_93ef_11ec_a811_0242ac110002row5_col8,#T_327ff2ee_93ef_11ec_a811_0242ac110002row5_col9,#T_327ff2ee_93ef_11ec_a811_0242ac110002row5_col10,#T_327ff2ee_93ef_11ec_a811_0242ac110002row5_col11,#T_327ff2ee_93ef_11ec_a811_0242ac110002row5_col12,#T_327ff2ee_93ef_11ec_a811_0242ac110002row5_col13,#T_327ff2ee_93ef_11ec_a811_0242ac110002row5_col14,#T_327ff2ee_93ef_11ec_a811_0242ac110002row5_col15,#T_327ff2ee_93ef_11ec_a811_0242ac110002row5_col16,#T_327ff2ee_93ef_11ec_a811_0242ac110002row5_col17,#T_327ff2ee_93ef_11ec_a811_0242ac110002row6_col1,#T_327ff2ee_93ef_11ec_a811_0242ac110002row6_col2,#T_327ff2ee_93ef_11ec_a811_0242ac110002row6_col3,#T_327ff2ee_93ef_11ec_a811_0242ac110002row6_col4,#T_327ff2ee_93ef_11ec_a811_0242ac110002row6_col5,#T_327ff2ee_93ef_11ec_a811_0242ac110002row6_col8,#T_327ff2ee_93ef_11ec_a811_0242ac110002row6_col11,#T_327ff2ee_93ef_11ec_a81 ...
# label test confusion_matrix
# <style  type="text/css" >
# #T_3287d20c_93ef_11ec_a811_0242ac110002row0_col0,#T_3287d20c_93ef_11ec_a811_0242ac110002row1_col1,#T_3287d20c_93ef_11ec_a811_0242ac110002row2_col2,#T_3287d20c_93ef_11ec_a811_0242ac110002row3_col3,#T_3287d20c_93ef_11ec_a811_0242ac110002row4_col4,#T_3287d20c_93ef_11ec_a811_0242ac110002row5_col5,#T_3287d20c_93ef_11ec_a811_0242ac110002row6_col6,#T_3287d20c_93ef_11ec_a811_0242ac110002row7_col7,#T_3287d20c_93ef_11ec_a811_0242ac110002row8_col8,#T_3287d20c_93ef_11ec_a811_0242ac110002row9_col9,#T_3287d20c_93ef_11ec_a811_0242ac110002row10_col10,#T_3287d20c_93ef_11ec_a811_0242ac110002row11_col11,#T_3287d20c_93ef_11ec_a811_0242ac110002row12_col12,#T_3287d20c_93ef_11ec_a811_0242ac110002row13_col13,#T_3287d20c_93ef_11ec_a811_0242ac110002row14_col14,#T_3287d20c_93ef_11ec_a811_0242ac110002row15_col15,#T_3287d20c_93ef_11ec_a811_0242ac110002row16_col16,#T_3287d20c_93ef_11ec_a811_0242ac110002row17_col17{
#             background-color:  #800026;
#             color:  #f1f1f1;
#         }#T_3287d20c_93ef_11ec_a811_0242ac110002row0_col1,#T_3287d20c_93ef_11ec_a811_0242ac110002row10_col7{
#             background-color:  #fff9bd;
#             color:  #000000;
#         }#T_3287d20c_93ef_11ec_a811_0242ac110002row0_col2,#T_3287d20c_93ef_11ec_a811_0242ac110002row0_col3,#T_3287d20c_93ef_11ec_a811_0242ac110002row0_col5,#T_3287d20c_93ef_11ec_a811_0242ac110002row0_col7,#T_3287d20c_93ef_11ec_a811_0242ac110002row0_col8,#T_3287d20c_93ef_11ec_a811_0242ac110002row0_col9,#T_3287d20c_93ef_11ec_a811_0242ac110002row0_col10,#T_3287d20c_93ef_11ec_a811_0242ac110002row0_col11,#T_3287d20c_93ef_11ec_a811_0242ac110002row0_col12,#T_3287d20c_93ef_11ec_a811_0242ac110002row0_col13,#T_3287d20c_93ef_11ec_a811_0242ac110002row0_col14,#T_3287d20c_93ef_11ec_a811_0242ac110002row0_col15,#T_3287d20c_93ef_11ec_a811_0242ac110002row0_col16,#T_3287d20c_93ef_11ec_a811_0242ac110002row0_col17,#T_3287d20c_93ef_11ec_a811_0242ac110002row1_col3,#T_3287d20c_93ef_11ec_a811_0242ac110002row1_col5,#T_3287d20c_93ef_11ec_a811_0242ac110002row1_col6,#T_3287d20c_93ef_11ec_a811_0242ac110002row1_col8,#T_3287d20c_93ef_11ec_a811_0242ac110002row1_col9,#T_3287d20c_93ef_11ec_a811_0242ac110002row1_col10,#T_3287d20c_93ef_11ec_a811_0242ac110002row1_col11,#T_3287d20c_93ef_11ec_a811_0242ac110002row1_col12,#T_3287d20c_93ef_11ec_a811_0242ac110002row1_col13,#T_3287d20c_93ef_11ec_a811_0242ac110002row1_col14,#T_3287d20c_93ef_11ec_a811_0242ac110002row1_col15,#T_3287d20c_93ef_11ec_a811_0242ac110002row1_col16,#T_3287d20c_93ef_11ec_a811_0242ac110002row1_col17,#T_3287d20c_93ef_11ec_a811_0242ac110002row2_col0,#T_3287d20c_93ef_11ec_a811_0242ac110002row2_col3,#T_3287d20c_93ef_11ec_a811_0242ac110002row2_col4,#T_3287d20c_93ef_11ec_a811_0242ac110002row2_col5,#T_3287d20c_93ef_11ec_a811_0242ac110002row2_col6,#T_3287d20c_93ef_11ec_a811_0242ac110002row2_col7,#T_3287d20c_93ef_11ec_a811_0242ac110002row2_col8,#T_3287d20c_93ef_11ec_a811_0242ac110002row2_col9,#T_3287d20c_93ef_11ec_a811_0242ac110002row2_col10,#T_3287d20c_93ef_11ec_a811_0242ac110002row2_col11,#T_3287d20c_93ef_11ec_a811_0242ac110002row2_col12,#T_3287d20c_93ef_11ec_a811_0242ac110002row2_col13,#T_3287d20c_93ef_11ec_a811_0242ac110002row2_col14,#T_3287d20c_93ef_11ec_a811_0242ac110002row2_col15,#T_3287d20c_93ef_11ec_a811_0242ac110002row2_col16,#T_3287d20c_93ef_11ec_a811_0242ac110002row2_col17,#T_3287d20c_93ef_11ec_a811_0242ac110002row3_col1,#T_3287d20c_93ef_11ec_a811_0242ac110002row3_col2,#T_3287d20c_93ef_11ec_a811_0242ac110002row3_col5,#T_3287d20c_93ef_11ec_a811_0242ac110002row3_col6,#T_3287d20c_93ef_11ec_a811_0242ac110002row3_col7,#T_3287d20c_93ef_11ec_a811_0242ac110002row3_col8,#T_3287d20c_93ef_11ec_a811_0242ac110002row3_col10,#T_3287d20c_93ef_11ec_a811_0242ac110002row3_col11,#T_3287d20c_93ef_11ec_a811_0242ac110002row3_col12,#T_3287d20c_93ef_11ec_a811_0242ac110002row3_col13,#T_3287d20c_93ef_11ec_a811_0242ac110002row3_col14,#T_3287d20c_93ef_11ec_a811_0242ac110002row3_col16,#T_3287d20c_93ef_11ec_a811_0242ac110002row3_col17,#T_3287d20c_93ef_11ec_a811_0242ac110002row4_col2,#T_3287d20c_93ef_11ec_a811_0242ac110002row4_col6,#T_3287d20c_93ef_11ec_a811_0242ac110002row4_col7,#T_3287d20c_93ef_11ec_a811_0242ac110002row4_col8,#T_3287d20c_93ef_11ec_a811_0242ac110002row4_col9,#T_3287d20c_93ef_11ec_a811_0242ac110002row4_col11,#T_3287d20c_93ef_11ec_a811_0242ac110002row4_col12,#T_3287d20c_93ef_11ec_a811_0242ac110002row4_col13,#T_3287d20c_93ef_11ec_a811_0242ac110002row4_col14,#T_3287d20c_93ef_11ec_a811_0242ac110002row4_col15,#T_3287d20c_93ef_11ec_a811_0242ac110002row4_col16,#T_3287d20c_93ef_11ec_a811_0242ac110002row4_col17,#T_3287d20c_93ef_11ec_a811_0242ac110002row5_col0,#T_3287d20c_93ef_11ec_a811_0242ac110002row5_col1,#T_3287d20c_93ef_11ec_a811_0242ac110002row5_col3,#T_3287d20c_93ef_11ec_a811_0242ac110002row5_col6,#T_3287d20c_93ef_11ec_a811_0242ac110002row5_col7,#T_3287d20c_93ef_11ec_a811_0242ac110002row5_col8,#T_3287d20c_93ef_11ec_a811_0242ac110002row5_col9,#T_3287d20c_93ef_11ec_a811_0242ac110002row5_col10,#T_3287d20c_93ef_11ec_a811_0242ac110002row5_col11,#T_3287d20c_93ef_11ec_a811_0242ac110002row5_col12,#T_3287d20c_93ef_11ec_a811_0242ac110002row5_col13,#T_3287d20c_93ef_11ec_a811_0242ac110002row5_col14,#T_3287d20c_93ef_11ec_a811_0 ...
# train fi : 0.772037909565838, train acc: 0.8681216931216931, test_f1 fi : 0.8299867529255176, test acc: 0.9095238095238095
#
# mask train confusion_matrix
# <style  type="text/css" >
# #T_328f534c_93ef_11ec_a811_0242ac110002row0_col0,#T_328f534c_93ef_11ec_a811_0242ac110002row1_col1,#T_328f534c_93ef_11ec_a811_0242ac110002row2_col2{
#             background-color:  #800026;
#             color:  #f1f1f1;
#         }#T_328f534c_93ef_11ec_a811_0242ac110002row0_col1{
#             background-color:  #fffcc4;
#             color:  #000000;
#         }#T_328f534c_93ef_11ec_a811_0242ac110002row0_col2,#T_328f534c_93ef_11ec_a811_0242ac110002row1_col2,#T_328f534c_93ef_11ec_a811_0242ac110002row2_col0,#T_328f534c_93ef_11ec_a811_0242ac110002row2_col1{
#             background-color:  #ffffcc;
#             color:  #000000;
#         }#T_328f534c_93ef_11ec_a811_0242ac110002row1_col0{
#             background-color:  #fffec9;
#             color:  #000000;
#         }</style><table id="T_328f534c_93ef_11ec_a811_0242ac110002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >2</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_328f534c_93ef_11ec_a811_0242ac110002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_328f534c_93ef_11ec_a811_0242ac110002row0_col0" class="data row0 col0" >10727</td>
#                         <td id="T_328f534c_93ef_11ec_a811_0242ac110002row0_col1" class="data row0 col1" >59</td>
#                         <td id="T_328f534c_93ef_11ec_a811_0242ac110002row0_col2" class="data row0 col2" >14</td>
#             </tr>
#             <tr>
#                         <th id="T_328f534c_93ef_11ec_a811_0242ac110002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_328f534c_93ef_11ec_a811_0242ac110002row1_col0" class="data row1 col0" >102</td>
#                         <td id="T_328f534c_93ef_11ec_a811_0242ac110002row1_col1" class="data row1 col1" >2043</td>
#                         <td id="T_328f534c_93ef_11ec_a811_0242ac110002row1_col2" class="data row1 col2" >15</td>
#             </tr>
#             <tr>
#                         <th id="T_328f534c_93ef_11ec_a811_0242ac110002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_328f534c_93ef_11ec_a811_0242ac110002row2_col0" class="data row2 col0" >17</td>
#                         <td id="T_328f534c_93ef_11ec_a811_0242ac110002row2_col1" class="data row2 col1" >8</td>
#                         <td id="T_328f534c_93ef_11ec_a811_0242ac110002row2_col2" class="data row2 col2" >2135</td>
#             </tr>
#     </tbody></table>
# mask test confusion_matrix
# <style  type="text/css" >
# #T_3290b8cc_93ef_11ec_a811_0242ac110002row0_col0,#T_3290b8cc_93ef_11ec_a811_0242ac110002row1_col1,#T_3290b8cc_93ef_11ec_a811_0242ac110002row2_col2{
#             background-color:  #800026;
#             color:  #f1f1f1;
#         }#T_3290b8cc_93ef_11ec_a811_0242ac110002row0_col1{
#             background-color:  #fffdc8;
#             color:  #000000;
#         }#T_3290b8cc_93ef_11ec_a811_0242ac110002row0_col2,#T_3290b8cc_93ef_11ec_a811_0242ac110002row1_col2,#T_3290b8cc_93ef_11ec_a811_0242ac110002row2_col0,#T_3290b8cc_93ef_11ec_a811_0242ac110002row2_col1{
#             background-color:  #ffffcc;
#             color:  #000000;
#         }#T_3290b8cc_93ef_11ec_a811_0242ac110002row1_col0{
#             background-color:  #fffecb;
#             color:  #000000;
#         }</style><table id="T_3290b8cc_93ef_11ec_a811_0242ac110002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >2</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3290b8cc_93ef_11ec_a811_0242ac110002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_3290b8cc_93ef_11ec_a811_0242ac110002row0_col0" class="data row0 col0" >2692</td>
#                         <td id="T_3290b8cc_93ef_11ec_a811_0242ac110002row0_col1" class="data row0 col1" >8</td>
#                         <td id="T_3290b8cc_93ef_11ec_a811_0242ac110002row0_col2" class="data row0 col2" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_3290b8cc_93ef_11ec_a811_0242ac110002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_3290b8cc_93ef_11ec_a811_0242ac110002row1_col0" class="data row1 col0" >20</td>
#                         <td id="T_3290b8cc_93ef_11ec_a811_0242ac110002row1_col1" class="data row1 col1" >519</td>
#                         <td id="T_3290b8cc_93ef_11ec_a811_0242ac110002row1_col2" class="data row1 col2" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_3290b8cc_93ef_11ec_a811_0242ac110002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_3290b8cc_93ef_11ec_a811_0242ac110002row2_col0" class="data row2 col0" >2</td>
#                         <td id="T_3290b8cc_93ef_11ec_a811_0242ac110002row2_col1" class="data row2 col1" >0</td>
#                         <td id="T_3290b8cc_93ef_11ec_a811_0242ac110002row2_col2" class="data row2 col2" >538</td>
#             </tr>
#     </tbody></table>
# train fi : 0.9785167431321989, train acc: 0.9857804232804233, test_f1 fi : 0.9881664839176422, test acc: 0.9917989417989418
#
# gender_group train confusion_matrix
# <style  type="text/css" >
# #T_32961934_93ef_11ec_a811_0242ac110002row0_col0,#T_32961934_93ef_11ec_a811_0242ac110002row1_col1{
#             background-color:  #800026;
#             color:  #f1f1f1;
#         }#T_32961934_93ef_11ec_a811_0242ac110002row0_col1,#T_32961934_93ef_11ec_a811_0242ac110002row1_col0{
#             background-color:  #ffffcc;
#             color:  #000000;
#         }</style><table id="T_32961934_93ef_11ec_a811_0242ac110002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_32961934_93ef_11ec_a811_0242ac110002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_32961934_93ef_11ec_a811_0242ac110002row0_col0" class="data row0 col0" >5500</td>
#                         <td id="T_32961934_93ef_11ec_a811_0242ac110002row0_col1" class="data row0 col1" >340</td>
#             </tr>
#             <tr>
#                         <th id="T_32961934_93ef_11ec_a811_0242ac110002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_32961934_93ef_11ec_a811_0242ac110002row1_col0" class="data row1 col0" >313</td>
#                         <td id="T_32961934_93ef_11ec_a811_0242ac110002row1_col1" class="data row1 col1" >8967</td>
#             </tr>
#     </tbody></table>
# gender_group test confusion_matrix
# <style  type="text/css" >
# #T_329721d0_93ef_11ec_a811_0242ac110002row0_col0,#T_329721d0_93ef_11ec_a811_0242ac110002row1_col1{
#             background-color:  #800026;
#             color:  #f1f1f1;
#         }#T_329721d0_93ef_11ec_a811_0242ac110002row0_col1,#T_329721d0_93ef_11ec_a811_0242ac110002row1_col0{
#             background-color:  #ffffcc;
#             color:  #000000;
#         }</style><table id="T_329721d0_93ef_11ec_a811_0242ac110002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_329721d0_93ef_11ec_a811_0242ac110002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_329721d0_93ef_11ec_a811_0242ac110002row0_col0" class="data row0 col0" >1409</td>
#                         <td id="T_329721d0_93ef_11ec_a811_0242ac110002row0_col1" class="data row0 col1" >52</td>
#             </tr>
#             <tr>
#                         <th id="T_329721d0_93ef_11ec_a811_0242ac110002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_329721d0_93ef_11ec_a811_0242ac110002row1_col0" class="data row1 col0" >51</td>
#                         <td id="T_329721d0_93ef_11ec_a811_0242ac110002row1_col1" class="data row1 col1" >2268</td>
#             </tr>
#     </tbody></table>
# train fi : 0.9544154232194952, train acc: 0.9568121693121693, test_f1 fi : 0.9712675211923618, test acc: 0.9727513227513227
#
# age_group train confusion_matrix
# <style  type="text/css" >
# #T_329c6c94_93ef_11ec_a811_0242ac110002row0_col0,#T_329c6c94_93ef_11ec_a811_0242ac110002row1_col1,#T_329c6c94_93ef_11ec_a811_0242ac110002row2_col2{
#             background-color:  #800026;
#             color:  #f1f1f1;
#         }#T_329c6c94_93ef_11ec_a811_0242ac110002row0_col1,#T_329c6c94_93ef_11ec_a811_0242ac110002row0_col2,#T_329c6c94_93ef_11ec_a811_0242ac110002row2_col0{
#             background-color:  #ffffcc;
#             color:  #000000;
#         }#T_329c6c94_93ef_11ec_a811_0242ac110002row1_col0{
#             background-color:  #fff5b5;
#             color:  #000000;
#         }#T_329c6c94_93ef_11ec_a811_0242ac110002row1_col2{
#             background-color:  #fc6832;
#             color:  #000000;
#         }#T_329c6c94_93ef_11ec_a811_0242ac110002row2_col1{
#             background-color:  #fffecb;
#             color:  #000000;
#         }</style><table id="T_329c6c94_93ef_11ec_a811_0242ac110002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >2</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_329c6c94_93ef_11ec_a811_0242ac110002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_329c6c94_93ef_11ec_a811_0242ac110002row0_col0" class="data row0 col0" >6625</td>
#                         <td id="T_329c6c94_93ef_11ec_a811_0242ac110002row0_col1" class="data row0 col1" >547</td>
#                         <td id="T_329c6c94_93ef_11ec_a811_0242ac110002row0_col2" class="data row0 col2" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_329c6c94_93ef_11ec_a811_0242ac110002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_329c6c94_93ef_11ec_a811_0242ac110002row1_col0" class="data row1 col0" >464</td>
#                         <td id="T_329c6c94_93ef_11ec_a811_0242ac110002row1_col1" class="data row1 col1" >6136</td>
#                         <td id="T_329c6c94_93ef_11ec_a811_0242ac110002row1_col2" class="data row1 col2" >272</td>
#             </tr>
#             <tr>
#                         <th id="T_329c6c94_93ef_11ec_a811_0242ac110002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_329c6c94_93ef_11ec_a811_0242ac110002row2_col0" class="data row2 col0" >15</td>
#                         <td id="T_329c6c94_93ef_11ec_a811_0242ac110002row2_col1" class="data row2 col1" >586</td>
#                         <td id="T_329c6c94_93ef_11ec_a811_0242ac110002row2_col2" class="data row2 col2" >473</td>
#             </tr>
#     </tbody></table>
# age_group test confusion_matrix
# <style  type="text/css" >
# #T_329dc008_93ef_11ec_a811_0242ac110002row0_col0,#T_329dc008_93ef_11ec_a811_0242ac110002row1_col1,#T_329dc008_93ef_11ec_a811_0242ac110002row2_col2{
#             background-color:  #800026;
#             color:  #f1f1f1;
#         }#T_329dc008_93ef_11ec_a811_0242ac110002row0_col1,#T_329dc008_93ef_11ec_a811_0242ac110002row0_col2,#T_329dc008_93ef_11ec_a811_0242ac110002row2_col0{
#             background-color:  #ffffcc;
#             color:  #000000;
#         }#T_329dc008_93ef_11ec_a811_0242ac110002row1_col0{
#             background-color:  #fff8bb;
#             color:  #000000;
#         }#T_329dc008_93ef_11ec_a811_0242ac110002row1_col2{
#             background-color:  #feb24c;
#             color:  #000000;
#         }#T_329dc008_93ef_11ec_a811_0242ac110002row2_col1{
#             background-color:  #fffbc2;
#             color:  #000000;
#         }</style><table id="T_329dc008_93ef_11ec_a811_0242ac110002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >2</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_329dc008_93ef_11ec_a811_0242ac110002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_329dc008_93ef_11ec_a811_0242ac110002row0_col0" class="data row0 col0" >1679</td>
#                         <td id="T_329dc008_93ef_11ec_a811_0242ac110002row0_col1" class="data row0 col1" >114</td>
#                         <td id="T_329dc008_93ef_11ec_a811_0242ac110002row0_col2" class="data row0 col2" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_329dc008_93ef_11ec_a811_0242ac110002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_329dc008_93ef_11ec_a811_0242ac110002row1_col0" class="data row1 col0" >82</td>
#                         <td id="T_329dc008_93ef_11ec_a811_0242ac110002row1_col1" class="data row1 col1" >1593</td>
#                         <td id="T_329dc008_93ef_11ec_a811_0242ac110002row1_col2" class="data row1 col2" >42</td>
#             </tr>
#             <tr>
#                         <th id="T_329dc008_93ef_11ec_a811_0242ac110002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_329dc008_93ef_11ec_a811_0242ac110002row2_col0" class="data row2 col0" >1</td>
#                         <td id="T_329dc008_93ef_11ec_a811_0242ac110002row2_col1" class="data row2 col1" >158</td>
#                         <td id="T_329dc008_93ef_11ec_a811_0242ac110002row2_col2" class="data row2 col2" >111</td>
#             </tr>
#     </tbody></table>
# train fi : 0.7717756776771866, train acc: 0.8752645502645503, test_f1 fi : 0.7862850075456334, test acc: 0.894973544973545
#
# ensemble_label train confusion_matrix
# <style  type="text/css" >
# #T_32a7da0c_93ef_11ec_a811_0242ac110002row0_col0,#T_32a7da0c_93ef_11ec_a811_0242ac110002row1_col1,#T_32a7da0c_93ef_11ec_a811_0242ac110002row2_col2,#T_32a7da0c_93ef_11ec_a811_0242ac110002row3_col3,#T_32a7da0c_93ef_11ec_a811_0242ac110002row4_col4,#T_32a7da0c_93ef_11ec_a811_0242ac110002row5_col5,#T_32a7da0c_93ef_11ec_a811_0242ac110002row6_col6,#T_32a7da0c_93ef_11ec_a811_0242ac110002row7_col7,#T_32a7da0c_93ef_11ec_a811_0242ac110002row8_col8,#T_32a7da0c_93ef_11ec_a811_0242ac110002row9_col9,#T_32a7da0c_93ef_11ec_a811_0242ac110002row10_col10,#T_32a7da0c_93ef_11ec_a811_0242ac110002row11_col11,#T_32a7da0c_93ef_11ec_a811_0242ac110002row12_col12,#T_32a7da0c_93ef_11ec_a811_0242ac110002row13_col13,#T_32a7da0c_93ef_11ec_a811_0242ac110002row14_col14,#T_32a7da0c_93ef_11ec_a811_0242ac110002row15_col15,#T_32a7da0c_93ef_11ec_a811_0242ac110002row16_col16,#T_32a7da0c_93ef_11ec_a811_0242ac110002row17_col17{
#             background-color:  #800026;
#             color:  #f1f1f1;
#         }#T_32a7da0c_93ef_11ec_a811_0242ac110002row0_col1,#T_32a7da0c_93ef_11ec_a811_0242ac110002row6_col7{
#             background-color:  #fff3ae;
#             color:  #000000;
#         }#T_32a7da0c_93ef_11ec_a811_0242ac110002row0_col2,#T_32a7da0c_93ef_11ec_a811_0242ac110002row0_col5,#T_32a7da0c_93ef_11ec_a811_0242ac110002row0_col8,#T_32a7da0c_93ef_11ec_a811_0242ac110002row0_col9,#T_32a7da0c_93ef_11ec_a811_0242ac110002row0_col10,#T_32a7da0c_93ef_11ec_a811_0242ac110002row0_col11,#T_32a7da0c_93ef_11ec_a811_0242ac110002row0_col13,#T_32a7da0c_93ef_11ec_a811_0242ac110002row0_col14,#T_32a7da0c_93ef_11ec_a811_0242ac110002row0_col15,#T_32a7da0c_93ef_11ec_a811_0242ac110002row0_col16,#T_32a7da0c_93ef_11ec_a811_0242ac110002row0_col17,#T_32a7da0c_93ef_11ec_a811_0242ac110002row1_col3,#T_32a7da0c_93ef_11ec_a811_0242ac110002row1_col6,#T_32a7da0c_93ef_11ec_a811_0242ac110002row1_col8,#T_32a7da0c_93ef_11ec_a811_0242ac110002row1_col9,#T_32a7da0c_93ef_11ec_a811_0242ac110002row1_col10,#T_32a7da0c_93ef_11ec_a811_0242ac110002row1_col11,#T_32a7da0c_93ef_11ec_a811_0242ac110002row1_col12,#T_32a7da0c_93ef_11ec_a811_0242ac110002row1_col14,#T_32a7da0c_93ef_11ec_a811_0242ac110002row1_col15,#T_32a7da0c_93ef_11ec_a811_0242ac110002row1_col16,#T_32a7da0c_93ef_11ec_a811_0242ac110002row1_col17,#T_32a7da0c_93ef_11ec_a811_0242ac110002row2_col0,#T_32a7da0c_93ef_11ec_a811_0242ac110002row2_col3,#T_32a7da0c_93ef_11ec_a811_0242ac110002row2_col4,#T_32a7da0c_93ef_11ec_a811_0242ac110002row2_col6,#T_32a7da0c_93ef_11ec_a811_0242ac110002row2_col9,#T_32a7da0c_93ef_11ec_a811_0242ac110002row2_col10,#T_32a7da0c_93ef_11ec_a811_0242ac110002row2_col11,#T_32a7da0c_93ef_11ec_a811_0242ac110002row2_col12,#T_32a7da0c_93ef_11ec_a811_0242ac110002row2_col13,#T_32a7da0c_93ef_11ec_a811_0242ac110002row2_col14,#T_32a7da0c_93ef_11ec_a811_0242ac110002row2_col15,#T_32a7da0c_93ef_11ec_a811_0242ac110002row2_col16,#T_32a7da0c_93ef_11ec_a811_0242ac110002row2_col17,#T_32a7da0c_93ef_11ec_a811_0242ac110002row3_col2,#T_32a7da0c_93ef_11ec_a811_0242ac110002row3_col6,#T_32a7da0c_93ef_11ec_a811_0242ac110002row3_col7,#T_32a7da0c_93ef_11ec_a811_0242ac110002row3_col8,#T_32a7da0c_93ef_11ec_a811_0242ac110002row3_col11,#T_32a7da0c_93ef_11ec_a811_0242ac110002row3_col12,#T_32a7da0c_93ef_11ec_a811_0242ac110002row3_col13,#T_32a7da0c_93ef_11ec_a811_0242ac110002row3_col14,#T_32a7da0c_93ef_11ec_a811_0242ac110002row3_col16,#T_32a7da0c_93ef_11ec_a811_0242ac110002row3_col17,#T_32a7da0c_93ef_11ec_a811_0242ac110002row4_col2,#T_32a7da0c_93ef_11ec_a811_0242ac110002row4_col6,#T_32a7da0c_93ef_11ec_a811_0242ac110002row4_col7,#T_32a7da0c_93ef_11ec_a811_0242ac110002row4_col8,#T_32a7da0c_93ef_11ec_a811_0242ac110002row4_col12,#T_32a7da0c_93ef_11ec_a811_0242ac110002row4_col13,#T_32a7da0c_93ef_11ec_a811_0242ac110002row4_col14,#T_32a7da0c_93ef_11ec_a811_0242ac110002row4_col15,#T_32a7da0c_93ef_11ec_a811_0242ac110002row4_col16,#T_32a7da0c_93ef_11ec_a811_0242ac110002row4_col17,#T_32a7da0c_93ef_11ec_a811_0242ac110002row5_col0,#T_32a7da0c_93ef_11ec_a811_0242ac110002row5_col3,#T_32a7da0c_93ef_11ec_a811_0242ac110002row5_col6,#T_32a7da0c_93ef_11ec_a811_0242ac110002row5_col7,#T_32a7da0c_93ef_11ec_a811_0242ac110002row5_col8,#T_32a7da0c_93ef_11ec_a811_0242ac110002row5_col9,#T_32a7da0c_93ef_11ec_a811_0242ac110002row5_col10,#T_32a7da0c_93ef_11ec_a811_0242ac110002row5_col11,#T_32a7da0c_93ef_11ec_a811_0242ac110002row5_col12,#T_32a7da0c_93ef_11ec_a811_0242ac110002row5_col14,#T_32a7da0c_93ef_11ec_a811_0242ac110002row5_col15,#T_32a7da0c_93ef_11ec_a811_0242ac110002row5_col16,#T_32a7da0c_93ef_11ec_a811_0242ac110002row5_col17,#T_32a7da0c_93ef_11ec_a811_0242ac110002row6_col1,#T_32a7da0c_93ef_11ec_a811_0242ac110002row6_col2,#T_32a7da0c_93ef_11ec_a811_0242ac110002row6_col3,#T_32a7da0c_93ef_11ec_a811_0242ac110002row6_col4,#T_32a7da0c_93ef_11ec_a811_0242ac110002row6_col5,#T_32a7da0c_93ef_11ec_a811_0242ac110002row6_col8,#T_32a7da0c_93ef_11ec_a811_0242ac110002row6_col10,#T_32a7da0c_93ef_11ec_a811_0242ac110002row6_col11,#T_32a7da0c_93ef_11ec_a811_0242ac110002row6_col13,#T_32a7da0c_93ef_11ec_a811_0242ac110002row6_col14,#T_32a7da0c_93ef_11ec_a811_0242ac110002row6_col15,#T_32a7da0c_93ef_11ec_a811_0242ac110002row6_col16,#T_32a7da0c_93ef_11ec_a8 ...
# ensemble_label test confusion_matrix
# <style  type="text/css" >
# #T_32afc082_93ef_11ec_a811_0242ac110002row0_col0,#T_32afc082_93ef_11ec_a811_0242ac110002row1_col1,#T_32afc082_93ef_11ec_a811_0242ac110002row2_col2,#T_32afc082_93ef_11ec_a811_0242ac110002row3_col3,#T_32afc082_93ef_11ec_a811_0242ac110002row4_col4,#T_32afc082_93ef_11ec_a811_0242ac110002row5_col5,#T_32afc082_93ef_11ec_a811_0242ac110002row6_col6,#T_32afc082_93ef_11ec_a811_0242ac110002row7_col7,#T_32afc082_93ef_11ec_a811_0242ac110002row8_col8,#T_32afc082_93ef_11ec_a811_0242ac110002row9_col9,#T_32afc082_93ef_11ec_a811_0242ac110002row10_col10,#T_32afc082_93ef_11ec_a811_0242ac110002row11_col11,#T_32afc082_93ef_11ec_a811_0242ac110002row12_col12,#T_32afc082_93ef_11ec_a811_0242ac110002row13_col13,#T_32afc082_93ef_11ec_a811_0242ac110002row14_col14,#T_32afc082_93ef_11ec_a811_0242ac110002row15_col15,#T_32afc082_93ef_11ec_a811_0242ac110002row16_col16,#T_32afc082_93ef_11ec_a811_0242ac110002row17_col17{
#             background-color:  #800026;
#             color:  #f1f1f1;
#         }#T_32afc082_93ef_11ec_a811_0242ac110002row0_col1{
#             background-color:  #fff4b0;
#             color:  #000000;
#         }#T_32afc082_93ef_11ec_a811_0242ac110002row0_col2,#T_32afc082_93ef_11ec_a811_0242ac110002row0_col4,#T_32afc082_93ef_11ec_a811_0242ac110002row0_col5,#T_32afc082_93ef_11ec_a811_0242ac110002row0_col6,#T_32afc082_93ef_11ec_a811_0242ac110002row0_col7,#T_32afc082_93ef_11ec_a811_0242ac110002row0_col8,#T_32afc082_93ef_11ec_a811_0242ac110002row0_col9,#T_32afc082_93ef_11ec_a811_0242ac110002row0_col10,#T_32afc082_93ef_11ec_a811_0242ac110002row0_col11,#T_32afc082_93ef_11ec_a811_0242ac110002row0_col12,#T_32afc082_93ef_11ec_a811_0242ac110002row0_col13,#T_32afc082_93ef_11ec_a811_0242ac110002row0_col14,#T_32afc082_93ef_11ec_a811_0242ac110002row0_col15,#T_32afc082_93ef_11ec_a811_0242ac110002row0_col16,#T_32afc082_93ef_11ec_a811_0242ac110002row0_col17,#T_32afc082_93ef_11ec_a811_0242ac110002row1_col3,#T_32afc082_93ef_11ec_a811_0242ac110002row1_col5,#T_32afc082_93ef_11ec_a811_0242ac110002row1_col6,#T_32afc082_93ef_11ec_a811_0242ac110002row1_col8,#T_32afc082_93ef_11ec_a811_0242ac110002row1_col9,#T_32afc082_93ef_11ec_a811_0242ac110002row1_col10,#T_32afc082_93ef_11ec_a811_0242ac110002row1_col11,#T_32afc082_93ef_11ec_a811_0242ac110002row1_col12,#T_32afc082_93ef_11ec_a811_0242ac110002row1_col13,#T_32afc082_93ef_11ec_a811_0242ac110002row1_col14,#T_32afc082_93ef_11ec_a811_0242ac110002row1_col15,#T_32afc082_93ef_11ec_a811_0242ac110002row1_col16,#T_32afc082_93ef_11ec_a811_0242ac110002row1_col17,#T_32afc082_93ef_11ec_a811_0242ac110002row2_col0,#T_32afc082_93ef_11ec_a811_0242ac110002row2_col3,#T_32afc082_93ef_11ec_a811_0242ac110002row2_col4,#T_32afc082_93ef_11ec_a811_0242ac110002row2_col5,#T_32afc082_93ef_11ec_a811_0242ac110002row2_col6,#T_32afc082_93ef_11ec_a811_0242ac110002row2_col8,#T_32afc082_93ef_11ec_a811_0242ac110002row2_col9,#T_32afc082_93ef_11ec_a811_0242ac110002row2_col10,#T_32afc082_93ef_11ec_a811_0242ac110002row2_col11,#T_32afc082_93ef_11ec_a811_0242ac110002row2_col12,#T_32afc082_93ef_11ec_a811_0242ac110002row2_col13,#T_32afc082_93ef_11ec_a811_0242ac110002row2_col14,#T_32afc082_93ef_11ec_a811_0242ac110002row2_col15,#T_32afc082_93ef_11ec_a811_0242ac110002row2_col16,#T_32afc082_93ef_11ec_a811_0242ac110002row2_col17,#T_32afc082_93ef_11ec_a811_0242ac110002row3_col2,#T_32afc082_93ef_11ec_a811_0242ac110002row3_col5,#T_32afc082_93ef_11ec_a811_0242ac110002row3_col6,#T_32afc082_93ef_11ec_a811_0242ac110002row3_col7,#T_32afc082_93ef_11ec_a811_0242ac110002row3_col8,#T_32afc082_93ef_11ec_a811_0242ac110002row3_col11,#T_32afc082_93ef_11ec_a811_0242ac110002row3_col12,#T_32afc082_93ef_11ec_a811_0242ac110002row3_col13,#T_32afc082_93ef_11ec_a811_0242ac110002row3_col14,#T_32afc082_93ef_11ec_a811_0242ac110002row3_col15,#T_32afc082_93ef_11ec_a811_0242ac110002row3_col16,#T_32afc082_93ef_11ec_a811_0242ac110002row3_col17,#T_32afc082_93ef_11ec_a811_0242ac110002row4_col0,#T_32afc082_93ef_11ec_a811_0242ac110002row4_col2,#T_32afc082_93ef_11ec_a811_0242ac110002row4_col6,#T_32afc082_93ef_11ec_a811_0242ac110002row4_col7,#T_32afc082_93ef_11ec_a811_0242ac110002row4_col8,#T_32afc082_93ef_11ec_a811_0242ac110002row4_col9,#T_32afc082_93ef_11ec_a811_0242ac110002row4_col11,#T_32afc082_93ef_11ec_a811_0242ac110002row4_col12,#T_32afc082_93ef_11ec_a811_0242ac110002row4_col13,#T_32afc082_93ef_11ec_a811_0242ac110002row4_col14,#T_32afc082_93ef_11ec_a811_0242ac110002row4_col15,#T_32afc082_93ef_11ec_a811_0242ac110002row4_col16,#T_32afc082_93ef_11ec_a811_0242ac110002row4_col17,#T_32afc082_93ef_11ec_a811_0242ac110002row5_col0,#T_32afc082_93ef_11ec_a811_0242ac110002row5_col2,#T_32afc082_93ef_11ec_a811_0242ac110002row5_col3,#T_32afc082_93ef_11ec_a811_0242ac110002row5_col6,#T_32afc082_93ef_11ec_a811_0242ac110002row5_col7,#T_32afc082_93ef_11ec_a811_0242ac110002row5_col8,#T_32afc082_93ef_11ec_a811_0242ac110002row5_col9,#T_32afc082_93ef_11ec_a811_0242ac110002row5_col10,#T_32afc082_93ef_11ec_a811_0242ac110002row5_col11,#T_32afc082_93ef_11ec_a811_0242ac110002row5_col12,#T_32afc082_93ef_11ec_a811_0242ac110002row5_col13,#T_32afc082_93ef_11ec_a811_0242ac110002row5_col14,#T_32afc082_93ef_11ec_a811_0 ...
# train fi : 0.7184064316568405, train acc: 0.8277116402116402, test_f1 fi : 0.7674285864154632, test acc: 0.8648148148148148

# %% [markdown]
# # 제출

# %%
# 예측에 사용할 라벨 결정
submission['ans'] = ensemble_submission_df['ensemble_label'].astype(int).values

# 제출할 파일을 저장합니다.
submission.to_csv(os.path.join(submission_data_dir, 'submission.csv'), index=False)
print('test inference is done!')
# Out:
# test inference is done!

# %%
submission.head()
# Out:
#                                         ImageID  ans
# 0  cbc5c6e168e63498590db46022617123f1fe1268.jpg   13
# 1  0e72482bf56b3581c081f7da2a6180b8792c7089.jpg    4
# 2  b549040c49190cedc41327748aeb197c1670f14d.jpg   16
# 3  4f9cb2a045c6d5b9e50ad3459ea7b791eb6e18bc.jpg   13
# 4  248428d9a4a5b6229a7081c32851b90cb8d38d0c.jpg   12
